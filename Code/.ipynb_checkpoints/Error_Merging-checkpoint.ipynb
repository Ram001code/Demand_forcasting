# %%
import numpy as np
import pandas as pd

# %%
Er_LSTM= pd.read_excel('C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Dataset\\Final Output\\Weekly\\Error_Output_all_LSTM_Weekly.xlsx')

# %%
Er_LSTM= Er_LSTM.rename(columns= {'MSE_Score': 'MSE_LSTM', 'RMSE_Score': 'RMSE_LSTM'})

# %%
Er_prophet = pd.read_excel('C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Dataset\\Final Output\\Weekly\\Prophet\\Error_Output_all_Prophet_Weekly.xlsx')

# %%
Er_prophet= Er_prophet.rename(columns= {'MSE_Score': 'MSE_prophet', 'RMSE_Score': 'RMSE_prophet'})

# %%
Er_Sarima = pd.read_excel('C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Dataset\\Final Output\\Weekly\\SARIMA\\Error_Output_all_SARIMA_Weekly.xlsx')

# %%
Er_Sarima= Er_Sarima.rename(columns= {'MSE_Score': 'MSE_sarima', 'RMSE_Score': 'RMSE_sarima'})

# %%
from functools import reduce

data_frames = [Er_LSTM, Er_prophet, Er_Sarima]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Location', 'Item'],
                                            how='inner'), data_frames)

# %%
df_merged
# Out:
#          MSE_LSTM   RMSE_LSTM                 Location               Item  \
# 0     8265.146159   90.912849                  FREMONT  CHICKEN XXXXX - O
# 1   329941.001681  574.404911                  FREMONT    DRUMSTICKS NNNN
# 2     2932.063427   54.148531                  FREMONT        FILLET QQQQ
# 3     5019.568427   70.848913                  HAYWARD  CHICKEN XXXXX - O
# 4   302172.924760  549.702578                  HAYWARD    DRUMSTICKS NNNN
# 5     4084.015982   63.906306                  HAYWARD        FILLET QQQQ
# 6     2380.277349   48.788086                 LAKEWOOD  CHICKEN XXXXX - O
# 7    82182.633869  286.675136                 LAKEWOOD    DRUMSTICKS NNNN
# 8     1766.706881   42.032212                 LAKEWOOD        FILLET QQQQ
# 9     8037.921751   89.654458              RICHMOND CA  CHICKEN XXXXX - O
# 10  351413.465363  592.801371              RICHMOND CA    DRUMSTICKS NNNN
# 11    6674.938691   81.700298              RICHMOND CA        FILLET QQQQ
# ...

# %%
df_merged= df_merged.reindex(columns=['Location', 'Item', 'MSE_LSTM', 'RMSE_LSTM', 'MSE_prophet', 'RMSE_prophet', 'MSE_sarima', 'RMSE_sarima'])

# %%
df_merged
# Out:
#                    Location               Item       MSE_LSTM   RMSE_LSTM  \
# 0                   FREMONT  CHICKEN XXXXX - O    8265.146159   90.912849
# 1                   FREMONT    DRUMSTICKS NNNN  329941.001681  574.404911
# 2                   FREMONT        FILLET QQQQ    2932.063427   54.148531
# 3                   HAYWARD  CHICKEN XXXXX - O    5019.568427   70.848913
# 4                   HAYWARD    DRUMSTICKS NNNN  302172.924760  549.702578
# 5                   HAYWARD        FILLET QQQQ    4084.015982   63.906306
# 6                  LAKEWOOD  CHICKEN XXXXX - O    2380.277349   48.788086
# 7                  LAKEWOOD    DRUMSTICKS NNNN   82182.633869  286.675136
# 8                  LAKEWOOD        FILLET QQQQ    1766.706881   42.032212
# 9               RICHMOND CA  CHICKEN XXXXX - O    8037.921751   89.654458
# 10              RICHMOND CA    DRUMSTICKS NNNN  351413.465363  592.801371
# 11              RICHMOND CA        FILLET QQQQ    6674.938691   81.700298
# ...

# %%
df_merged.to_excel('Combine_Error_Output_Weekly_All.xlsx', index=False)
