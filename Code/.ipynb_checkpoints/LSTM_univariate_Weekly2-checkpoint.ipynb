# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
loc= 'C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Dataset\\'


data= pd.read_excel(loc + 'combine_data20-22.xlsx', index_col ='Date',parse_dates = True)
data.head()
# Out:
#            Country State     Region District  Location Major Department  \
# Date
# 2020-01-02      US    CA  LA REGION      LA3  LAKEWOOD       FRESH FOOD
# 2020-01-02      US    CA  LA REGION      LA3  LAKEWOOD       FRESH FOOD
# 2020-01-02      US    CA   BAY AREA      BA3   HAYWARD       FRESH FOOD
# 2020-01-02      US    CA  LA REGION      LA3  LAKEWOOD       FRESH FOOD
# 2020-01-02      US    CA   BAY AREA      BA3   HAYWARD       FRESH FOOD
#
#            Department Category       Group             Item Category  \
# Date
# 2020-01-02    61 MEAT   6 MEAT  64 POULTRY  640 CONVENTIONAL CHICKEN
# 2020-01-02    61 MEAT   6 MEAT  64 POULTRY     645 CHICKEN XXXXX - O
# 2020-01-02    61 MEAT   6 MEAT  68 SEAFOOD    680 FRESH FISH FILLETS
# 2020-01-02    61 MEAT   6 MEAT  68 SEAFOOD    680 FRESH FISH FILLETS
# 2020-01-02    61 MEAT   6 MEAT  64 POULTRY     645 CHICKEN XXXXX - O
#
#                          Item   Quantity  Amount
# Date
# 2020-01-02    DRUMSTICKS NNNN  172.55461  205.34
# 2020-01-02  CHICKEN XXXXX - O   45.85170  228.80
# 2020-01-02        FILLET QQQQ   60.41915  422.33
# 2020-01-02        FILLET QQQQ   36.49069  255.07
# 2020-01-02  CHICKEN XXXXX - O   90.86774  453.43

# %%
data.shape
# Out:
# (12456, 13)

# %%
import copy
data_df= copy.deepcopy(data)

# %%
data_df.head()
# Out:
#            Country State     Region District  Location Major Department  \
# Date
# 2020-01-02      US    CA  LA REGION      LA3  LAKEWOOD       FRESH FOOD
# 2020-01-02      US    CA  LA REGION      LA3  LAKEWOOD       FRESH FOOD
# 2020-01-02      US    CA   BAY AREA      BA3   HAYWARD       FRESH FOOD
# 2020-01-02      US    CA  LA REGION      LA3  LAKEWOOD       FRESH FOOD
# 2020-01-02      US    CA   BAY AREA      BA3   HAYWARD       FRESH FOOD
#
#            Department Category       Group             Item Category  \
# Date
# 2020-01-02    61 MEAT   6 MEAT  64 POULTRY  640 CONVENTIONAL CHICKEN
# 2020-01-02    61 MEAT   6 MEAT  64 POULTRY     645 CHICKEN XXXXX - O
# 2020-01-02    61 MEAT   6 MEAT  68 SEAFOOD    680 FRESH FISH FILLETS
# 2020-01-02    61 MEAT   6 MEAT  68 SEAFOOD    680 FRESH FISH FILLETS
# 2020-01-02    61 MEAT   6 MEAT  64 POULTRY     645 CHICKEN XXXXX - O
#
#                          Item   Quantity  Amount
# Date
# 2020-01-02    DRUMSTICKS NNNN  172.55461  205.34
# 2020-01-02  CHICKEN XXXXX - O   45.85170  228.80
# 2020-01-02        FILLET QQQQ   60.41915  422.33
# 2020-01-02        FILLET QQQQ   36.49069  255.07
# 2020-01-02  CHICKEN XXXXX - O   90.86774  453.43

# %%
# Using resample  it fills NaN when a week is missed,

'''

data['Date'] = pd.to_datetime(data['date'], format="%Y%m%d")
# Refer to: https://www.techtrekking.com/how-to-convert-daily-time-series-data-into-weekly-and-monthly-using-pandas-and-python/
# and here: https://stackoverflow.com/a/60518425/5449346
# and this: https://github.com/pandas-dev/pandas/issues/11217#issuecomment-145253671
logic = {'o'  : 'first',
         'h'  : 'max',
         'l'   : 'min',
         'c' : 'last',
         'Date': 'first',
         }
data = data.groupby([data['Date'].dt.year, data['Date'].dt.week]).agg(logic)
data.set_index('Date', inplace=True)

 '''
# Out:
# '\n\ndata[\'Date\'] = pd.to_datetime(data[\'date\'], format="%Y%m%d")\n# Refer to: https://www.techtrekking.com/how-to-convert-daily-time-series-data-into-weekly-and-monthly-using-pandas-and-python/\n# and here: https://stackoverflow.com/a/60518425/5449346\n# and this: https://github.com/pandas-dev/pandas/issues/11217#issuecomment-145253671\nlogic = {\'o\'  : \'first\',\n         \'h\'  : \'max\',\n         \'l\'   : \'min\',\n         \'c\' : \'last\',\n         \'Date\': \'first\',\n         }\ndata = data.groupby([data[\'Date\'].dt.year, data[\'Date\'].dt.week]).agg(logic)\ndata.set_index(\'Date\', inplace=True)\n\n '

# %%
data_df= data_df[['Location', 'Item', 'Quantity', 'Amount']]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12456 entries, 2020-01-02 to 2022-11-27
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Location  12456 non-null  object
#  1   Item      12456 non-null  object
#  2   Quantity  12456 non-null  float64
#  3   Amount    12456 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 486.6+ KB

# %%
# data_df= data_df.set_index('Date')

# %%
data_df1= data_df.groupby(['Location', 'Item']).resample('W').mean().dropna()

# %%
data_df_new = data_df1.reset_index()

# %%
data_df_new.columns
# Out:
# Index(['Location', 'Item', 'Date', 'Quantity', 'Amount'], dtype='object')

# %%
# data_df_new.set_index('Date', inplace=True)

# %%
data_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Location  2127 non-null   object
#  1   Item      2127 non-null   object
#  2   Date      2127 non-null   datetime64[ns]
#  3   Quantity  2127 non-null   float64
#  4   Amount    2127 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 83.2+ KB

# %%
data_df_new.isnull().sum()
# Out:
# Location    0
# Item        0
# Date        0
# Quantity    0
# Amount      0
# dtype: int64

# %%
data_df_new.head()
# Out:
#   Location               Item       Date   Quantity      Amount
# 0  FREMONT  CHICKEN XXXXX - O 2020-01-05  37.023380  184.746667
# 1  FREMONT  CHICKEN XXXXX - O 2020-01-12  41.889780  209.030000
# 2  FREMONT  CHICKEN XXXXX - O 2020-01-19  86.101210  429.645000
# 3  FREMONT  CHICKEN XXXXX - O 2020-01-26  63.834068  318.532000
# 4  FREMONT  CHICKEN XXXXX - O 2020-02-02  45.320977  226.151667

# %%
data_df_new[data_df_new['Quantity'].isna()]
# Out:
# Empty DataFrame
# Columns: [Location, Item, Date, Quantity, Amount]
# Index: []

# %%
# data_df_new.to_excel('Data_Weekly.xlsx', index=False)

# %%
data_df_new= data_df_new.set_index('Date')

# %% [markdown]
# ### Single Location and item Seasonality

# %%
data_df2= data_df_new[(data_df_new['Location']== 'FREMONT') & (data_df_new['Item']== 'CHICKEN XXXXX - O')]

# %%
plt.figure(figsize=(16,6))
data_df2['Quantity'].plot()
plt.title('Quantity - Weekly')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# data_df2['Date']= pd.to_datetime(data_df2['Date'])
result=seasonal_decompose(data_df2['Quantity'], 
                          model='multiplicable')

# %%
result.plot()

# %%
result2 =seasonal_decompose(data_df2['Quantity'], model='additive')

# %%
result2.plot()

# %%
# result.seasonal.plot()
# result.trend.plot()
# result.resid.plot()

# %%
season_out1= pd.DataFrame()

season_out1['Trend'] = result.trend
season_out1['seasonal']  = result.seasonal
season_out1['resid']  = result.resid

# %%
season_out1
# Out:
#             Trend  seasonal  resid
# Date
# 2020-01-05    NaN  1.468230    NaN
# 2020-01-12    NaN  0.959438    NaN
# 2020-01-19    NaN  1.609120    NaN
# 2020-01-26    NaN  1.455692    NaN
# 2020-02-02    NaN  1.121424    NaN
# ...           ...       ...    ...
# 2022-10-30    NaN  0.919939    NaN
# 2022-11-06    NaN  0.836428    NaN
# 2022-11-13    NaN  0.857282    NaN
# 2022-11-20    NaN  1.345557    NaN
# 2022-11-27    NaN  0.829352    NaN
#
# [152 rows x 3 columns]

# %%
df = pd.concat([data_df2,season_out1], axis=1 )

# %%
df
# Out:
#     Location               Item       Date   Quantity      Amount      Trend  \
# 0    FREMONT  CHICKEN XXXXX - O 2020-01-05  37.023380  184.746667  37.023380
# 1    FREMONT  CHICKEN XXXXX - O 2020-01-12  41.889780  209.030000  41.889780
# 2    FREMONT  CHICKEN XXXXX - O 2020-01-19  86.101210  429.645000  86.101210
# 3    FREMONT  CHICKEN XXXXX - O 2020-01-26  63.834068  318.532000  63.834068
# 4    FREMONT  CHICKEN XXXXX - O 2020-02-02  45.320977  226.151667  45.320977
# ..       ...                ...        ...        ...         ...        ...
# 147  FREMONT  CHICKEN XXXXX - O 2022-10-30  38.625329  231.365714  38.625329
# 148  FREMONT  CHICKEN XXXXX - O 2022-11-06  52.301170  313.284000  52.301170
# 149  FREMONT  CHICKEN XXXXX - O 2022-11-13  41.523016  248.722857  41.523016
# 150  FREMONT  CHICKEN XXXXX - O 2022-11-20  36.942523  221.285714  36.942523
# 151  FREMONT  CHICKEN XXXXX - O 2022-11-27  28.980247  173.591667  28.980247
#
#      seasonal  resid
# 0         1.0    1.0
# 1         1.0    1.0
# 2         1.0    1.0
# 3         1.0    1.0
# 4         1.0    1.0
# ..        ...    ...
# 147       1.0    1.0
# 148       1.0    1.0
# 149       1.0    1.0
# 150       1.0    1.0
# 151       1.0    1.0
#
# [152 rows x 8 columns]

# %% [markdown]
# ### All Location and Item seasonality

# %%
data_df_new['Location'].unique()
# Out:
# array(['FREMONT', 'HAYWARD', 'LAKEWOOD', 'RICHMOND CA',
#        'S SAN FRANCISCO BUS CTR'], dtype=object)

# %%
data_df_new['Item'].unique()
# Out:
# array(['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ',
#        'BEEF OOOO - GT'], dtype=object)

# %%
data_df_new.head()
# Out:
#   Location               Item       Date   Quantity      Amount
# 0  FREMONT  CHICKEN XXXXX - O 2020-01-05  37.023380  184.746667
# 1  FREMONT  CHICKEN XXXXX - O 2020-01-12  41.889780  209.030000
# 2  FREMONT  CHICKEN XXXXX - O 2020-01-19  86.101210  429.645000
# 3  FREMONT  CHICKEN XXXXX - O 2020-01-26  63.834068  318.532000
# 4  FREMONT  CHICKEN XXXXX - O 2020-02-02  45.320977  226.151667

# %%
for i in data_df_new['Location'].unique():
    df= data_df_new[data_df_new['Location']==i]
    for j in df['Item'].unique():
        item_data= df[df["Item"]==j]
        
        item_data= item_data.drop(['Location', 'Item'], axis=1)
#         train_dates = pd.to_datetime(item_data['Date']) 
        item_data.set_index('Date')
#         print(item_data)
        time_series = item_data.index  #Get dates for test data
        
        
        result=seasonal_decompose(item_data['Quantity'], model='multiplicable', period=1)
        
        #Results
        se_out= pd.DataFrame()
        se_out['Trend'] = result.trend
        se_out['seasonality']  = result.seasonal
        se_out['remainder']  = result.resid
#         se_out['Date']= train_dates.values
        df_out = pd.concat([item_data,se_out], axis=1 )
    
        
        #Saving Results 
        df_out['Location']= i
        df_out['Item']=j
        
        predction_output = "ModelOut\seasonality\Weekly\season_" +i+"-"+j+".xlsx"
        df_out.to_excel(predction_output, index= False)
#         print(df_out)

# %%
import pandas as pd
import os
import glob

# %%
path = 'C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Code\\ModelOut\\seasonality\\Weekly'
out_files = glob.glob(os.path.join(path, "*.xlsx"))
   
dfs= []


for f in out_files:
    dfs.append(pd.read_excel(f))
df_season=pd.concat(dfs, ignore_index=True)

# %%
df_season.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         2127 non-null   datetime64[ns]
#  1   Quantity     2127 non-null   float64
#  2   Amount       2127 non-null   float64
#  3   Trend        2127 non-null   float64
#  4   seasonality  2127 non-null   int64
#  5   remainder    2127 non-null   int64
#  6   Location     2127 non-null   object
#  7   Item         2127 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 133.1+ KB

# %%
# df.to_excel('Seasonality_all_Weekly.xlsx', index=False)

# %% [markdown]
# ## Modelling

# %%
data_df_new.shape
# Out:
# (2127, 5)

# %%
data_df_new.head()
# Out:
#   Location               Item       Date   Quantity      Amount
# 0  FREMONT  CHICKEN XXXXX - O 2020-01-05  37.023380  184.746667
# 1  FREMONT  CHICKEN XXXXX - O 2020-01-12  41.889780  209.030000
# 2  FREMONT  CHICKEN XXXXX - O 2020-01-19  86.101210  429.645000
# 3  FREMONT  CHICKEN XXXXX - O 2020-01-26  63.834068  318.532000
# 4  FREMONT  CHICKEN XXXXX - O 2020-02-02  45.320977  226.151667

# %%
# df_new = data_df_new.loc[data_df_new['Date'] <= '2022-04-01']

# %%
# df_new.shape

# %%
# df_new

# %%
data_df2 = data_df_new[(data_df_new['Location']=='HAYWARD') & (data_df_new['Item']== 'FILLET QQQQ')]

# %%
data_df2
# Out:
#     Location         Item       Date   Quantity      Amount
# 759  HAYWARD  FILLET QQQQ 2020-01-05  65.401283  457.155000
# 760  HAYWARD  FILLET QQQQ 2020-01-12  55.853830  411.631429
# 761  HAYWARD  FILLET QQQQ 2020-01-19  51.600041  386.484286
# 762  HAYWARD  FILLET QQQQ 2020-01-26  49.255580  368.924286
# 763  HAYWARD  FILLET QQQQ 2020-02-02  54.503147  408.228571
# ..       ...          ...        ...        ...         ...
# 906  HAYWARD  FILLET QQQQ 2022-10-30  58.501193  525.925714
# 907  HAYWARD  FILLET QQQQ 2022-11-06  59.796919  537.574286
# 908  HAYWARD  FILLET QQQQ 2022-11-13  56.444627  507.437143
# 909  HAYWARD  FILLET QQQQ 2022-11-20  47.658516  428.450000
# 910  HAYWARD  FILLET QQQQ 2022-11-27  52.739893  474.131667
#
# [152 rows x 5 columns]

# %%
data_df2 = data_df2.drop(['Location', 'Item', 'Amount'], axis=1)

# %%
train = data_df2[data_df2['Date']<= '2022-05-01']
test = data_df2[data_df2['Date']>= '2022-05-01']

# %%
train.tail()
# Out:
#           Date   Quantity
# 876 2022-04-03  43.015232
# 877 2022-04-10  40.339430
# 878 2022-04-17  61.482602
# 879 2022-04-24  42.748017
# 880 2022-05-01  48.851277

# %%
train= train.set_index('Date')
test= test.set_index('Date')

# %%
train.shape, test.shape
# Out:
# ((122, 1), (31, 1))

# %%
# data_df2

# %%
# data_df2.shape

# %%
# a= int(len(data_df2)*0.80)

# train,test = data_df2[:a], data_df2[a:]


from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train) 

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)

# %%
train.shape, test.shape
# Out:
# ((122, 1), (31, 1))

# %%
test.head()
# Out:
#              Quantity
# Date
# 2022-05-01  48.851277
# 2022-05-08  61.969966
# 2022-05-15  45.556532
# 2022-05-22  55.421352
# 2022-05-29  62.942934

# %%
#Empty lists to be populated using formatted training data
trainX = []
trainY = []

n_future = 1   # Number of days we want to look into the future based on the past days.
n_past=seq_size = 7  # Number of past days we want to use to predict the future.
n_features = 1 ## number of features. This dataset is univariate so it is 1

#Reformat input data into a shape: (n_samples x timesteps x n_features)

for i in range(n_past, len(train_scaled) - n_future +1):
    trainX.append(train_scaled[i - n_past:i, 0:train.shape[1]])
    trainY.append(train_scaled[i + n_future - 1:i + n_future, 0])

# %%
trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))
# Out:
# trainX shape == (115, 7, 1).
# trainY shape == (115, 1).

# %%
model = Sequential()
model.add(LSTM(128, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=True))
model.add(Dropout(0.2))
# model.add(Dropout(0.2))
model.add(LSTM(16, activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(Dropout(0.2))
model.add(LSTM(8, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dropout(0.2))
model.add(Dense(5))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_181 (LSTM)             (None, 7, 128)            66560
#
#  lstm_182 (LSTM)             (None, 7, 64)             49408
#
#  lstm_183 (LSTM)             (None, 7, 64)             33024
#
#  lstm_184 (LSTM)             (None, 7, 32)             12416
#
#  dropout_157 (Dropout)       (None, 7, 32)             0
#
#  lstm_185 (LSTM)             (None, 7, 16)             3136
#
#  dropout_158 (Dropout)       (None, 7, 16)             0
#
#  dropout_159 (Dropout)       (None, 7, 16)             0
#
#  lstm_186 (LSTM)             (None, 8)                 800
#
#  dropout_160 (Dropout)       (None, 8)                 0
#
#  dropout_161 (Dropout)       (None, 8)                 0
#
#  dense_63 (Dense)            (None, 5)                 45
#
#  dense_64 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 165,395
# Trainable params: 165,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(trainX, trainY, epochs=30, batch_size=16, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/30
# 6/6 [==============================] - 11s 218ms/step - loss: 0.4411 - val_loss: 0.2856
# Epoch 2/30
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4097 - val_loss: 0.2510
# Epoch 3/30
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3756 - val_loss: 0.2115
# Epoch 4/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3302 - val_loss: 0.1624
# Epoch 5/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2725 - val_loss: 0.1070
# Epoch 6/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2426 - val_loss: 0.1076
# Epoch 7/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.2156 - val_loss: 0.1089
# Epoch 8/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1923 - val_loss: 0.1033
# Epoch 9/30
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1941 - val_loss: 0.1045
# Epoch 10/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1855 - val_loss: 0.1066
# Epoch 11/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1893 - val_loss: 0.1112
# Epoch 12/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1867 - val_loss: 0.1065
# Epoch 13/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.2071 - val_loss: 0.1045
# Epoch 14/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1967 - val_loss: 0.1064
# Epoch 15/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1572 - val_loss: 0.1067
# Epoch 16/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1775 - val_loss: 0.1054
# Epoch 17/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1604 - val_loss: 0.1033
# Epoch 18/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1895 - val_loss: 0.1079
# Epoch 19/30
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1883 - val_loss: 0.1047
# Epoch 20/30
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1804 - val_loss: 0.1028
# Epoch 21/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1815 - val_loss: 0.1046
# Epoch 22/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1678 - val_loss: 0.1150
# Epoch 23/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1443 - val_loss: 0.1075
# Epoch 24/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1598 - val_loss: 0.1063
# Epoch 25/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1678 - val_loss: 0.1083
# Epoch 26/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1544 - val_loss: 0.1063
# Epoch 27/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1703 - val_loss: 0.1030
# Epoch 28/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1753 - val_loss: 0.1040
# Epoch 29/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1530 - val_loss: 0.1083
# Epoch 30/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1424 - val_loss: 0.1056

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
trainPredict = model.predict(trainX)
train_inverse = scaler.inverse_transform(train_scaled)
# Out:
# 4/4 [==============================] - 1s 20ms/step

# %%
trainPredict.shape,train_inverse.shape
# Out:
# ((115, 1), (122, 1))

# %%
n_past=7        #1 means-1 week back
train_inverse[n_past:].shape
# Out:
# (115, 1)

# %%
# calculate root mean squared error
import math
from sklearn.metrics import mean_squared_error
n_past=7

trainScore = mean_squared_error(train_inverse[n_past:], trainPredict[:,0])
print('Train Score: %.2f MSE' % (trainScore))

trainScore = math.sqrt(mean_squared_error(train_inverse[n_past:], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 3534.43 MSE
# Train Score: 59.45 RMSE

# %%
testPredict = model.predict(test)
test_inverse = scaler.inverse_transform(test_scaled)
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
# calculate root mean squared error

testScore = mean_squared_error(test_inverse[:], testPredict[:,0])
print('Test Score: %.2f MSE' % (testScore))

testScore = math.sqrt(mean_squared_error(test_inverse[:], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 3344.69 MSE
# Test Score: 57.83 RMSE

# %%
n_past= seq_size= 1          # 1 means-1 week back
n_days_for_prediction = 36  #let us predict past 12 days


# from pandas.tseries.holiday import USFederalHolidayCalendar
# from pandas.tseries.offsets import CustomBusinessDay
# us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())


# train_dates = pd.to_datetime(data_df2['Date'])
time_series = test.index

# %%
time_series
# Out:
# DatetimeIndex(['2022-05-01', '2022-05-08', '2022-05-15', '2022-05-22',
#                '2022-05-29', '2022-06-05', '2022-06-12', '2022-06-19',
#                '2022-06-26', '2022-07-03', '2022-07-10', '2022-07-17',
#                '2022-07-24', '2022-07-31', '2022-08-07', '2022-08-14',
#                '2022-08-21', '2022-08-28', '2022-09-04', '2022-09-11',
#                '2022-09-18', '2022-09-25', '2022-10-02', '2022-10-09',
#                '2022-10-16', '2022-10-23', '2022-10-30', '2022-11-06',
#                '2022-11-13', '2022-11-20', '2022-11-27'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
# time_series[-1]

# %%
# pd.date_range(list(time_series)[-1], periods=n_days_for_prediction, freq='D')

# %%
# predict_period_dates = pd.date_range(list(time_series)[-1], periods=n_days_for_prediction, freq='W').tolist()
# print(predict_period_dates)

# %%
# len(trainX)

# %%
# len(trainX[-n_days_for_prediction:])

# %%
prediction = model.predict(test)
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
prediction.shape
# Out:
# (31, 1)

# %%
### Inverse transform to before scaling so we get actual numbers
rescaled_prediction = scaler.inverse_transform(prediction)[:,0]

# Convert timestamp to date
forecast_dates = []
for time_i in time_series:
    forecast_dates.append(time_i.date())
    
df_forecast= pd.DataFrame({'Date':np.array(forecast_dates), 'Quantity':rescaled_prediction})
df_forecast['Date']=pd.to_datetime(df_forecast['Date'])

# %%
df_forecast
# Out:
#          Date   Quantity
# 0  2022-05-01  52.900826
# 1  2022-05-08  51.051712
# 2  2022-05-15  53.522114
# 3  2022-05-22  51.905952
# 4  2022-05-29  50.927265
# 5  2022-06-05  53.990677
# 6  2022-06-12  52.152798
# 7  2022-06-19  50.942314
# 8  2022-06-26  50.584911
# 9  2022-07-03  50.504787
# 10 2022-07-10  50.900990
# 11 2022-07-17  50.968830
# 12 2022-07-24  50.550194
# 13 2022-07-31  51.072906
# 14 2022-08-07  50.870594
# 15 2022-08-14  50.715210
# 16 2022-08-21  51.953129
# 17 2022-08-28  51.872917
# 18 2022-09-04  53.273079
# 19 2022-09-11  50.637894
# 20 2022-09-18  51.148075
# 21 2022-09-25  52.227077
# 22 2022-10-02  52.644596
# 23 2022-10-09  49.973202
# 24 2022-10-16  52.185390
# 25 2022-10-23  51.710274
# 26 2022-10-30  51.497452
# 27 2022-11-06  51.330063
# 28 2022-11-13  51.767963
# 29 2022-11-20  53.113182
# 30 2022-11-27  52.284237

# %%
#reset index
# data_df3= data_df2.reset_index()

original = data_df2[['Date', 'Quantity']]
original['Date']=pd.to_datetime(original['Date'])
original = original.loc[original['Date'] >= '2020-05-01']

# %%
original
# Out:
#           Date   Quantity
# 776 2020-05-03  91.691595
# 777 2020-05-10  66.485787
# 778 2020-05-17  85.927339
# 779 2020-05-24  89.692927
# 780 2020-05-31  74.962173
# ..         ...        ...
# 906 2022-10-30  58.501193
# 907 2022-11-06  59.796919
# 908 2022-11-13  56.444627
# 909 2022-11-20  47.658516
# 910 2022-11-27  52.739893
#
# [135 rows x 2 columns]

# %%
plt.figure(figsize=(13,8)) 
lineplt= sns.lineplot(original['Date'], original['Quantity'])
sns.lineplot(df_forecast['Date'], df_forecast['Quantity'])
# lineplt.set(title = 'SAN FRANCISCO--> BEEF OOOO - GT')
plt.show()
# Out:
# C:\Users\Ramshankar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ramshankar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## All items and Locations

# %%
data_df_new.shape
# Out:
# (2127, 5)

# %%
# df_new = data_df_new.loc[data_df_new['Date'] <= '2022-04-01']

# %%
# df_new.tail()
# Out:
#                      Location             Item       Date    Quantity  \
# 2122  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-10-30  113.512925
# 2123  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-11-06   97.404393
# 2124  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-11-13   93.240305
# 2125  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-11-20   94.381132
# 2126  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-11-27   88.660853
#
#           Amount
# 2122  146.431667
# 2123  125.651667
# 2124  120.280000
# 2125  121.751667
# 2126  114.372500

# %%
data_df= data_df_new.copy()

# %%
for i in data_df["Location"].unique():
    df= data_df[data_df['Location']==i]
    print(i, " , ", list(df['Item'].unique()))
# Out:
# FREMONT  ,  ['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ']
# HAYWARD  ,  ['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ']
# LAKEWOOD  ,  ['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ']
# RICHMOND CA  ,  ['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ']
# S SAN FRANCISCO BUS CTR  ,  ['BEEF OOOO - GT', 'DRUMSTICKS NNNN']

# %%
for i in data_df['Location'].unique():
    df= data_df[data_df['Location']==i]
    for j in df['Item'].unique():
        item_data= df[df["Item"]==j]

        item_data= item_data.drop(['Location', 'Item', 'Amount'], axis=1)
        train_dates = pd.to_datetime(item_data['Date'])  #collecting date 
#         item_data = item_data.set_index('Date')
#         print(item_data)
        
        #Modelling 
        train = item_data[item_data['Date']<= '2022-05-01']
        test = item_data[item_data['Date']>= '2022-05-01']
        
        train= train.set_index('Date')
        test= test.set_index('Date')
        #Splitting 
#         a= int(len(item_data)*0.75)
#         train,test = item_data[:a], item_data[a:]
        
        #COnverting into same scale 
        from sklearn.preprocessing import MinMaxScaler
        scaler = MinMaxScaler()
        scaler.fit(train) 
        
        #Transforming train and test 
        train_scaled = scaler.transform(train)
        test_scaled = scaler.transform(test)
        
        #Empty lists to be populated using formatted training data
        trainX = []
        trainY = []

        n_future = 1   # Number of days we want to look into the future based on the past days.
        n_past=seq_size = 7  # Number of past days we want to use to predict the future.
        n_features = 1 ## number of features. This dataset is univariate so it is 1

        #Reformat input data into a shape: (n_samples x timesteps x n_features)

        for num in range(n_past, len(train_scaled) - n_future +1):
            trainX.append(train_scaled[num - n_past:num, 0:train.shape[1]])
            trainY.append(train_scaled[num + n_future - 1:num + n_future, 0])
        
        #Converting to Numpy format
        trainX, trainY = np.array(trainX), np.array(trainY)
        
#         print(f'Location: {i} and  Item: {j}')
        
#         print('trainX shape == {}.'.format(trainX.shape))
#         print('trainY shape == {}.'.format(trainY.shape))
        
#         print("\n")
        print(f"LSTM Archtitecture {i}--> {j}")
        
        model = Sequential()
        model.add(LSTM(128, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
        model.add(LSTM(64, activation='relu', return_sequences=True))
        model.add(LSTM(64, activation='relu', return_sequences=True))
        model.add(LSTM(32, activation='relu', return_sequences=True))
        model.add(Dropout(0.2))
        # model.add(Dropout(0.2))
        model.add(LSTM(16, activation='relu', return_sequences=True))
        model.add(Dropout(0.2))
        model.add(Dropout(0.2))
        model.add(LSTM(8, activation='relu', return_sequences=False))
        model.add(Dropout(0.2))
        model.add(Dropout(0.2))
        model.add(Dense(5))
        model.add(Dense(1))

        model.compile(optimizer='adam', loss='mae')
#         model.summary()

#         model.summary()
#         print("\n")
        print(f"Model Training: {i}--> {j}")
        history = model.fit(trainX, trainY, epochs=30, batch_size=16, validation_split=0.2, verbose=1)
        
        #Plotting traning and validation curve 
        print("\n")
        print(f"Plot for: {i}--> {j}")
        title = i+"-->"+j
        
#         ax.set_title(title)
#         plt.plot(history.history['loss'], label='Training loss')
#         plt.plot(history.history['val_loss'], label='Validation loss')
#         ax.set_ylabel('Quantity')
#         ax.set_xlabel('Date')
#         plt.legend()
        
        print("\n")
        
        print(f"Model Forecasting initated: {i}--> {j}")

        n_past= seq_size= 1        #Number of past days we want to use to predict the future.
#         n_days_for_prediction = 36     #let us predict past 12 days
        
        time_series = test.index  #Get dates for test data
        
        #Creating date time periods for next 90 days 
#         predict_period_dates = pd.date_range(list(time_series)[-n_past], periods=n_days_for_prediction, freq='W').tolist()
        
        print(f"Model prediction initiated : {i}--> {j}")
        #Make prediction
        prediction = model.predict(test) #shape = (n, 1) where n is the n_days_for_prediction
        
        ### Inverse transform to before scaling so we get actual numbers
        rescaled_prediction = scaler.inverse_transform(prediction)[:,0]
        
        print(f"Model prediction completed : {i}--> {j}")
        # Convert timestamp to date
        forecast_dates = []
        for time_i in time_series:
            forecast_dates.append(time_i.date())
        
        print(f"Storing prediction into DataFrame : {i}--> {j}")
        print("\n")
        
        #Creating/saving prediction into dataframe 
        df_forecast= pd.DataFrame({'Date':np.array(forecast_dates), 'Forecasted_Qty':rescaled_prediction})
        df_forecast['Date']=pd.to_datetime(df_forecast['Date'])
        
        
        
        #reset index
#         data_df2= item_data.reset_index()
        
#         original = data_df2[['Date', 'Quantity']]
#         original['Date']=pd.to_datetime(original['Date'])
#         original = original.loc[original['Date'] >= '2020-01-02']
        
#         original= original.tail(90)
        
#         print("\n")
        print(f"Plotting prediction with original data : {i}--> {j}")
        
#         plt.figure(figsize=(10,10)) 
#         sns.lineplot(original['Date'], original['Quantity'])
#         sns.lineplot(df_forecast['Date'], df_forecast['Quantity'])
#         print(f"Model Forecasting complted  : {i}--> {j}")
   
        print("\n")
        print(f"Calculating MSE and RMSE : {i}--> {j}")
        #Prediction testing
        testPredict = model.predict(test)
        test_inverse = scaler.inverse_transform(test_scaled)

        import math
        from sklearn.metrics import mean_squared_error
#         n_past1=7

        # calculate root mean squared error

        MSE_Score = mean_squared_error(test_inverse[:], testPredict[:,0])
        print('Test Score: %.2f MSE' % (MSE_Score))

        RMSE_Score = math.sqrt(mean_squared_error(test_inverse[:], testPredict[:,0]))
        print('Test Score: %.2f RMSE' % (RMSE_Score))
        
        #Saving Results 
        df_forecast['Location']= i
        df_forecast['Item']=j
        
        print("\n")
        print(f'Writing predicted results of {i} and {j}')
        predction_output = "ModelOut\All_out\Weekly\Output\Output -" +i+"-"+j+".xlsx"
        df_forecast.to_excel(predction_output, index= False)
        
        col_names =  ['MSE_Score', 'RMSE_Score']
        Error_matric= pd.DataFrame(columns = col_names)
        
        my_out = {'MSE_Score': MSE_Score, 'RMSE_Score': RMSE_Score}
        Error_matric.loc[len(Error_matric)] = my_out 
        
        Error_matric['Location']=i
        Error_matric['Item']=j
        
        print(f'Writing error matrices of {i} and {j}')
        print("\n")
        Error_output = "ModelOut\All_out\Weekly\Error\Output_Error -" +i+"-"+j+".xlsx"
        Error_matric.to_excel(Error_output, index= False)
# Out:
# LSTM Archtitecture FREMONT--> CHICKEN XXXXX - O
# Model Training: FREMONT--> CHICKEN XXXXX - O
# Epoch 1/30
# 6/6 [==============================] - 10s 256ms/step - loss: 0.3604 - val_loss: 0.1553
# Epoch 2/30
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3318 - val_loss: 0.1249
# Epoch 3/30
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2987 - val_loss: 0.0929
# Epoch 4/30
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2609 - val_loss: 0.0635
# Epoch 5/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2148 - val_loss: 0.0729
# Epoch 6/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1747 - val_loss: 0.1177
# Epoch 7/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1751 - val_loss: 0.1404
# Epoch 8/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1773 - val_loss: 0.1175
# Epoch 9/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1649 - val_loss: 0.1109
# Epoch 10/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1645 - val_loss: 0.1146
# Epoch 11/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1640 - val_loss: 0.1209
# Epoch 12/30
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1475 - val_loss: 0.1283
# Epoch 13/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1647 - val_loss: 0.1307
# Epoch 14/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1613 - val_loss: 0.1336
# Epoch 15/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1664 - val_loss: 0.1341
# Epoch 16/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1642 - val_loss: 0.1319
# Epoch 17/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1388 - val_loss: 0.1355
# Epoch 18/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1483 - val_loss: 0.1333
# Epoch 19/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1538 - val_loss: 0.1341
# Epoch 20/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1514 - val_loss: 0.1328
# Epoch 21/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1508 - val_loss: 0.1395
# Epoch 22/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1397 - val_loss: 0.1386
# Epoch 23/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1520 - val_loss: 0.1362
# Epoch 24/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1485 - val_loss: 0.1354
# Epoch 25/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1530 - val_loss: 0.1395
# Epoch 26/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1532 - val_loss: 0.1374
# Epoch 27/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1608 - val_loss: 0.1287
# Epoch 28/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1529 - val_loss: 0.1302
# Epoch 29/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1514 - val_loss: 0.1281
# Epoch 30/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1489 - val_loss: 0.1262
#
#
# Plot for: FREMONT--> CHICKEN XXXXX - O
#
#
# Model Forecasting initated: FREMONT--> CHICKEN XXXXX - O
# Model prediction initiated : FREMONT--> CHICKEN XXXXX - O
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_187_input'), name='lstm_187_input', description="created by layer 'lstm_187_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 1s/step
# Model prediction completed : FREMONT--> CHICKEN XXXXX - O
# Storing prediction into DataFrame : FREMONT--> CHICKEN XXXXX - O
#
#
# Plotting prediction with original data : FREMONT--> CHICKEN XXXXX - O
#
#
# Calculating MSE and RMSE : FREMONT--> CHICKEN XXXXX - O
# 1/1 [==============================] - 0s 24ms/step
# Test Score: 1446.58 MSE
# Test Score: 38.03 RMSE
#
#
# Writing predicted results of FREMONT and CHICKEN XXXXX - O
# Writing error matrices of FREMONT and CHICKEN XXXXX - O
#
#
# LSTM Archtitecture FREMONT--> DRUMSTICKS NNNN
# Model Training: FREMONT--> DRUMSTICKS NNNN
# Epoch 1/30
# 6/6 [==============================] - 11s 215ms/step - loss: 0.4904 - val_loss: 0.4997
# Epoch 2/30
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4547 - val_loss: 0.4612
# Epoch 3/30
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4149 - val_loss: 0.4136
# Epoch 4/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3636 - val_loss: 0.3447
# Epoch 5/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2858 - val_loss: 0.2075
# Epoch 6/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2183 - val_loss: 0.1363
# Epoch 7/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1954 - val_loss: 0.1595
# Epoch 8/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1768 - val_loss: 0.1766
# Epoch 9/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1750 - val_loss: 0.1685
# Epoch 10/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1557 - val_loss: 0.1467
# Epoch 11/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1349 - val_loss: 0.1241
# Epoch 12/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1718 - val_loss: 0.1294
# Epoch 13/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1429 - val_loss: 0.1340
# Epoch 14/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1380 - val_loss: 0.1309
# Epoch 15/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1394 - val_loss: 0.1301
# Epoch 16/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1490 - val_loss: 0.1379
# Epoch 17/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1385 - val_loss: 0.1356
# Epoch 18/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1392 - val_loss: 0.1331
# Epoch 19/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1383 - val_loss: 0.1350
# Epoch 20/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1314 - val_loss: 0.1374
# Epoch 21/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1434 - val_loss: 0.1314
# Epoch 22/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1271 - val_loss: 0.1252
# Epoch 23/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1233 - val_loss: 0.1223
# Epoch 24/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1378 - val_loss: 0.1264
# Epoch 25/30
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1252 - val_loss: 0.1339
# Epoch 26/30
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1382 - val_loss: 0.1383
# Epoch 27/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1404 - val_loss: 0.1324
# Epoch 28/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1361 - val_loss: 0.1273
# Epoch 29/30
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1323 - val_loss: 0.1284
# Epoch 30/30
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1326 - val_loss: 0.1390
#
#
# Plot for: FREMONT--> DRUMSTICKS NNNN
#
#
# Model Forecasting initated: FREMONT--> DRUMSTICKS NNNN
# Model prediction initiated : FREMONT--> DRUMSTICKS NNNN
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_193_input'), name='lstm_193_input', description="created by layer 'lstm_193_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 2s 2s/step
# Model prediction completed : FREMONT--> DRUMSTICKS NNNN
# Storing prediction into DataFrame : FREMONT--> DRUMSTICKS NNNN
#
#
# Plotting prediction with original data : FREMONT--> DRUMSTICKS NNNN
#
#
# Calculating MSE and RMSE : FREMONT--> DRUMSTICKS NNNN
# 1/1 [==============================] - 0s 6ms/step
# Test Score: 365311.76 MSE
# Test Score: 604.41 RMSE
#
#
# Writing predicted results of FREMONT and DRUMSTICKS NNNN
# Writing error matrices of FREMONT and DRUMSTICKS NNNN
#
#
# LSTM Archtitecture FREMONT--> FILLET QQQQ
# Model Training: FREMONT--> FILLET QQQQ
# Epoch 1/30
# 6/6 [==============================] - 11s 268ms/step - loss: 0.3459 - val_loss: 0.2180
# Epoch 2/30
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2976 - val_loss: 0.1647
# Epoch 3/30
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2471 - val_loss: 0.1197
# Epoch 4/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2057 - val_loss: 0.1104
# Epoch 5/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1908 - val_loss: 0.1355
# Epoch 6/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1741 - val_loss: 0.1185
# Epoch 7/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1758 - val_loss: 0.1117
# Epoch 8/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1813 - val_loss: 0.1114
# Epoch 9/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1927 - val_loss: 0.1140
# Epoch 10/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1715 - val_loss: 0.1221
# Epoch 11/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1640 - val_loss: 0.1158
# Epoch 12/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1577 - val_loss: 0.1103
# Epoch 13/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1646 - val_loss: 0.1077
# Epoch 14/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1702 - val_loss: 0.1088
# Epoch 15/30
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1590 - val_loss: 0.1098
# Epoch 16/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1548 - val_loss: 0.1084
# Epoch 17/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1654 - val_loss: 0.1083
# Epoch 18/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1517 - val_loss: 0.1085
# Epoch 19/30
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1561 - val_loss: 0.1101
# Epoch 20/30
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1441 - val_loss: 0.1125
# Epoch 21/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1578 - val_loss: 0.1091
# Epoch 22/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1497 - val_loss: 0.1093
# Epoch 23/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1526 - val_loss: 0.1135
# Epoch 24/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1567 - val_loss: 0.1085
# Epoch 25/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1413 - val_loss: 0.1110
# Epoch 26/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1408 - val_loss: 0.1183
# Epoch 27/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1519 - val_loss: 0.1196
# Epoch 28/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1465 - val_loss: 0.1123
# Epoch 29/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1439 - val_loss: 0.1081
# Epoch 30/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1502 - val_loss: 0.1106
#
#
# Plot for: FREMONT--> FILLET QQQQ
#
#
# Model Forecasting initated: FREMONT--> FILLET QQQQ
# Model prediction initiated : FREMONT--> FILLET QQQQ
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_199_input'), name='lstm_199_input', description="created by layer 'lstm_199_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 2s 2s/step
# Model prediction completed : FREMONT--> FILLET QQQQ
# Storing prediction into DataFrame : FREMONT--> FILLET QQQQ
#
#
# Plotting prediction with original data : FREMONT--> FILLET QQQQ
#
#
# Calculating MSE and RMSE : FREMONT--> FILLET QQQQ
# 1/1 [==============================] - 0s 25ms/step
# Test Score: 1802.03 MSE
# Test Score: 42.45 RMSE
#
#
# Writing predicted results of FREMONT and FILLET QQQQ
# Writing error matrices of FREMONT and FILLET QQQQ
#
#
# LSTM Archtitecture HAYWARD--> CHICKEN XXXXX - O
# Model Training: HAYWARD--> CHICKEN XXXXX - O
# Epoch 1/30
# 6/6 [==============================] - 11s 223ms/step - loss: 0.2882 - val_loss: 0.0584
# Epoch 2/30
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2515 - val_loss: 0.0461
# Epoch 3/30
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2095 - val_loss: 0.0733
# Epoch 4/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1707 - val_loss: 0.1460
# Epoch 5/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1668 - val_loss: 0.1461
# Epoch 6/30
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1595 - val_loss: 0.1400
# Epoch 7/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1603 - val_loss: 0.1430
# Epoch 8/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1481 - val_loss: 0.1530
# Epoch 9/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1582 - val_loss: 0.1596
# Epoch 10/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1470 - val_loss: 0.1604
# Epoch 11/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1449 - val_loss: 0.1619
# Epoch 12/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1417 - val_loss: 0.1562
# Epoch 13/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1530 - val_loss: 0.1559
# Epoch 14/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1410 - val_loss: 0.1615
# Epoch 15/30
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1426 - val_loss: 0.1611
# Epoch 16/30
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1439 - val_loss: 0.1600
# Epoch 17/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1369 - val_loss: 0.1596
# Epoch 18/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1391 - val_loss: 0.1635
# Epoch 19/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1321 - val_loss: 0.1618
# Epoch 20/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1324 - val_loss: 0.1693
# Epoch 21/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1385 - val_loss: 0.1791
# Epoch 22/30
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1394 - val_loss: 0.1781
# Epoch 23/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1435 - val_loss: 0.1596
# Epoch 24/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1410 - val_loss: 0.1483
# Epoch 25/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1372 - val_loss: 0.1513
# Epoch 26/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1367 - val_loss: 0.1718
# Epoch 27/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1452 - val_loss: 0.1854
# Epoch 28/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1388 - val_loss: 0.1754
# Epoch 29/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1392 - val_loss: 0.1601
# Epoch 30/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1401 - val_loss: 0.1597
#
#
# Plot for: HAYWARD--> CHICKEN XXXXX - O
#
#
# Model Forecasting initated: HAYWARD--> CHICKEN XXXXX - O
# Model prediction initiated : HAYWARD--> CHICKEN XXXXX - O
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_205_input'), name='lstm_205_input', description="created by layer 'lstm_205_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 986ms/step
# Model prediction completed : HAYWARD--> CHICKEN XXXXX - O
# Storing prediction into DataFrame : HAYWARD--> CHICKEN XXXXX - O
#
#
# Plotting prediction with original data : HAYWARD--> CHICKEN XXXXX - O
#
#
# Calculating MSE and RMSE : HAYWARD--> CHICKEN XXXXX - O
# 1/1 [==============================] - 0s 31ms/step
# Test Score: 847.64 MSE
# Test Score: 29.11 RMSE
#
#
# Writing predicted results of HAYWARD and CHICKEN XXXXX - O
# Writing error matrices of HAYWARD and CHICKEN XXXXX - O
#
#
# LSTM Archtitecture HAYWARD--> DRUMSTICKS NNNN
# Model Training: HAYWARD--> DRUMSTICKS NNNN
# Epoch 1/30
# 6/6 [==============================] - 10s 253ms/step - loss: 0.5338 - val_loss: 0.5935
# Epoch 2/30
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4984 - val_loss: 0.5562
# Epoch 3/30
# 6/6 [==============================] - 0s 32ms/step - loss: 0.4613 - val_loss: 0.5148
# Epoch 4/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.4199 - val_loss: 0.4646
# Epoch 5/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.3665 - val_loss: 0.3902
# Epoch 6/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3045 - val_loss: 0.1885
# Epoch 7/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2259 - val_loss: 0.1595
# Epoch 8/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2130 - val_loss: 0.1911
# Epoch 9/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1974 - val_loss: 0.1682
# Epoch 10/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1755 - val_loss: 0.1228
# Epoch 11/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1759 - val_loss: 0.1134
# Epoch 12/30
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1853 - val_loss: 0.1230
# Epoch 13/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1919 - val_loss: 0.1385
# Epoch 14/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1601 - val_loss: 0.1424
# Epoch 15/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1695 - val_loss: 0.1479
# Epoch 16/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1959 - val_loss: 0.1407
# Epoch 17/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1751 - val_loss: 0.1313
# Epoch 18/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1689 - val_loss: 0.1323
# Epoch 19/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1742 - val_loss: 0.1340
# Epoch 20/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1613 - val_loss: 0.1375
# Epoch 21/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1571 - val_loss: 0.1309
# Epoch 22/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1653 - val_loss: 0.1190
# Epoch 23/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1620 - val_loss: 0.1151
# Epoch 24/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1616 - val_loss: 0.1194
# Epoch 25/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1674 - val_loss: 0.1316
# Epoch 26/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1606 - val_loss: 0.1403
# Epoch 27/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1629 - val_loss: 0.1300
# Epoch 28/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1580 - val_loss: 0.1259
# Epoch 29/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1584 - val_loss: 0.1258
# Epoch 30/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1589 - val_loss: 0.1270
#
#
# Plot for: HAYWARD--> DRUMSTICKS NNNN
#
#
# Model Forecasting initated: HAYWARD--> DRUMSTICKS NNNN
# Model prediction initiated : HAYWARD--> DRUMSTICKS NNNN
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_211_input'), name='lstm_211_input', description="created by layer 'lstm_211_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 1s/step
# Model prediction completed : HAYWARD--> DRUMSTICKS NNNN
# Storing prediction into DataFrame : HAYWARD--> DRUMSTICKS NNNN
#
#
# Plotting prediction with original data : HAYWARD--> DRUMSTICKS NNNN
#
#
# Calculating MSE and RMSE : HAYWARD--> DRUMSTICKS NNNN
# 1/1 [==============================] - 0s 9ms/step
# Test Score: 321031.35 MSE
# Test Score: 566.60 RMSE
#
#
# Writing predicted results of HAYWARD and DRUMSTICKS NNNN
# Writing error matrices of HAYWARD and DRUMSTICKS NNNN
#
#
# LSTM Archtitecture HAYWARD--> FILLET QQQQ
# Model Training: HAYWARD--> FILLET QQQQ
# Epoch 1/30
# 6/6 [==============================] - 10s 225ms/step - loss: 0.4451 - val_loss: 0.2970
# Epoch 2/30
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4250 - val_loss: 0.2755
# Epoch 3/30
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4025 - val_loss: 0.2521
# Epoch 4/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3787 - val_loss: 0.2264
# Epoch 5/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3519 - val_loss: 0.1949
# Epoch 6/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.3161 - val_loss: 0.1567
# Epoch 7/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2631 - val_loss: 0.1058
# Epoch 8/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2183 - val_loss: 0.1102
# Epoch 9/30
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1903 - val_loss: 0.1023
# Epoch 10/30
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1872 - val_loss: 0.1031
# Epoch 11/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1860 - val_loss: 0.1078
# Epoch 12/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1835 - val_loss: 0.1155
# Epoch 13/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1853 - val_loss: 0.1134
# Epoch 14/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1987 - val_loss: 0.1054
# Epoch 15/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1815 - val_loss: 0.1047
# Epoch 16/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1903 - val_loss: 0.1067
# Epoch 17/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1690 - val_loss: 0.1215
# Epoch 18/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1644 - val_loss: 0.1086
# Epoch 19/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1730 - val_loss: 0.1043
# Epoch 20/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1827 - val_loss: 0.1043
# Epoch 21/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1566 - val_loss: 0.1098
# Epoch 22/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1746 - val_loss: 0.1126
# Epoch 23/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1773 - val_loss: 0.1039
# Epoch 24/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1621 - val_loss: 0.1057
# Epoch 25/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1639 - val_loss: 0.1100
# Epoch 26/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1566 - val_loss: 0.1054
# Epoch 27/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1606 - val_loss: 0.1070
# Epoch 28/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1506 - val_loss: 0.1094
# Epoch 29/30
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1589 - val_loss: 0.1055
# Epoch 30/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1612 - val_loss: 0.1041
#
#
# Plot for: HAYWARD--> FILLET QQQQ
#
#
# Model Forecasting initated: HAYWARD--> FILLET QQQQ
# Model prediction initiated : HAYWARD--> FILLET QQQQ
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_217_input'), name='lstm_217_input', description="created by layer 'lstm_217_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 826ms/step
# Model prediction completed : HAYWARD--> FILLET QQQQ
# Storing prediction into DataFrame : HAYWARD--> FILLET QQQQ
#
#
# Plotting prediction with original data : HAYWARD--> FILLET QQQQ
#
#
# Calculating MSE and RMSE : HAYWARD--> FILLET QQQQ
# 1/1 [==============================] - 0s 36ms/step
# Test Score: 3324.73 MSE
# Test Score: 57.66 RMSE
#
#
# Writing predicted results of HAYWARD and FILLET QQQQ
# Writing error matrices of HAYWARD and FILLET QQQQ
#
#
# LSTM Archtitecture LAKEWOOD--> CHICKEN XXXXX - O
# Model Training: LAKEWOOD--> CHICKEN XXXXX - O
# Epoch 1/30
# 6/6 [==============================] - 11s 223ms/step - loss: 0.3720 - val_loss: 0.1899
# Epoch 2/30
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3289 - val_loss: 0.1533
# Epoch 3/30
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2849 - val_loss: 0.1142
# Epoch 4/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2283 - val_loss: 0.0917
# Epoch 5/30
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1822 - val_loss: 0.1312
# Epoch 6/30
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1831 - val_loss: 0.1409
# Epoch 7/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1767 - val_loss: 0.1206
# Epoch 8/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1568 - val_loss: 0.1159
# Epoch 9/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1544 - val_loss: 0.1224
# Epoch 10/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1588 - val_loss: 0.1318
# Epoch 11/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1606 - val_loss: 0.1443
# Epoch 12/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1565 - val_loss: 0.1520
# Epoch 13/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1455 - val_loss: 0.1549
# Epoch 14/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1404 - val_loss: 0.1553
# Epoch 15/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1427 - val_loss: 0.1581
# Epoch 16/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1307 - val_loss: 0.1669
# Epoch 17/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1304 - val_loss: 0.1736
# Epoch 18/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1383 - val_loss: 0.1736
# Epoch 19/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1268 - val_loss: 0.1657
# Epoch 20/30
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1456 - val_loss: 0.1492
# Epoch 21/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1322 - val_loss: 0.1482
# Epoch 22/30
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1358 - val_loss: 0.1574
# Epoch 23/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1344 - val_loss: 0.1636
# Epoch 24/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1248 - val_loss: 0.1708
# Epoch 25/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1218 - val_loss: 0.1752
# Epoch 26/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1295 - val_loss: 0.1723
# Epoch 27/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1253 - val_loss: 0.1720
# Epoch 28/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1298 - val_loss: 0.1709
# Epoch 29/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1323 - val_loss: 0.1703
# Epoch 30/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1272 - val_loss: 0.1753
#
#
# Plot for: LAKEWOOD--> CHICKEN XXXXX - O
#
#
# Model Forecasting initated: LAKEWOOD--> CHICKEN XXXXX - O
# Model prediction initiated : LAKEWOOD--> CHICKEN XXXXX - O
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_223_input'), name='lstm_223_input', description="created by layer 'lstm_223_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 901ms/step
# Model prediction completed : LAKEWOOD--> CHICKEN XXXXX - O
# Storing prediction into DataFrame : LAKEWOOD--> CHICKEN XXXXX - O
#
#
# Plotting prediction with original data : LAKEWOOD--> CHICKEN XXXXX - O
#
#
# Calculating MSE and RMSE : LAKEWOOD--> CHICKEN XXXXX - O
# 1/1 [==============================] - 0s 13ms/step
# Test Score: 1174.70 MSE
# Test Score: 34.27 RMSE
#
#
# Writing predicted results of LAKEWOOD and CHICKEN XXXXX - O
# Writing error matrices of LAKEWOOD and CHICKEN XXXXX - O
#
#
# LSTM Archtitecture LAKEWOOD--> DRUMSTICKS NNNN
# Model Training: LAKEWOOD--> DRUMSTICKS NNNN
# Epoch 1/30
# 6/6 [==============================] - 12s 232ms/step - loss: 0.2625 - val_loss: 0.4064
# Epoch 2/30
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2232 - val_loss: 0.3623
# Epoch 3/30
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1801 - val_loss: 0.3059
# Epoch 4/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1441 - val_loss: 0.2312
# Epoch 5/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1531 - val_loss: 0.1962
# Epoch 6/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1261 - val_loss: 0.2047
# Epoch 7/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1216 - val_loss: 0.2079
# Epoch 8/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1300 - val_loss: 0.2193
# Epoch 9/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1132 - val_loss: 0.2241
# Epoch 10/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1058 - val_loss: 0.2125
# Epoch 11/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1180 - val_loss: 0.2047
# Epoch 12/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1019 - val_loss: 0.1907
# Epoch 13/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1093 - val_loss: 0.1854
# Epoch 14/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1041 - val_loss: 0.1978
# Epoch 15/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1106 - val_loss: 0.2059
# Epoch 16/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1080 - val_loss: 0.2070
# Epoch 17/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1042 - val_loss: 0.2082
# Epoch 18/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1047 - val_loss: 0.1994
# Epoch 19/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1046 - val_loss: 0.1983
# Epoch 20/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1068 - val_loss: 0.1984
# Epoch 21/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1030 - val_loss: 0.1961
# Epoch 22/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1056 - val_loss: 0.2017
# Epoch 23/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1092 - val_loss: 0.2024
# Epoch 24/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1047 - val_loss: 0.2030
# Epoch 25/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1023 - val_loss: 0.2047
# Epoch 26/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1040 - val_loss: 0.2029
# Epoch 27/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1061 - val_loss: 0.2076
# Epoch 28/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1038 - val_loss: 0.2039
# Epoch 29/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1010 - val_loss: 0.1948
# Epoch 30/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1026 - val_loss: 0.1938
#
#
# Plot for: LAKEWOOD--> DRUMSTICKS NNNN
#
#
# Model Forecasting initated: LAKEWOOD--> DRUMSTICKS NNNN
# Model prediction initiated : LAKEWOOD--> DRUMSTICKS NNNN
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_229_input'), name='lstm_229_input', description="created by layer 'lstm_229_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 949ms/step
# Model prediction completed : LAKEWOOD--> DRUMSTICKS NNNN
# Storing prediction into DataFrame : LAKEWOOD--> DRUMSTICKS NNNN
#
#
# Plotting prediction with original data : LAKEWOOD--> DRUMSTICKS NNNN
#
#
# Calculating MSE and RMSE : LAKEWOOD--> DRUMSTICKS NNNN
# 1/1 [==============================] - 0s 23ms/step
# Test Score: 90856.28 MSE
# Test Score: 301.42 RMSE
#
#
# Writing predicted results of LAKEWOOD and DRUMSTICKS NNNN
# Writing error matrices of LAKEWOOD and DRUMSTICKS NNNN
#
#
# LSTM Archtitecture LAKEWOOD--> FILLET QQQQ
# Model Training: LAKEWOOD--> FILLET QQQQ
# Epoch 1/30
# 6/6 [==============================] - 12s 277ms/step - loss: 0.4003 - val_loss: 0.5090
# Epoch 2/30
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3743 - val_loss: 0.4786
# Epoch 3/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3435 - val_loss: 0.4465
# Epoch 4/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3112 - val_loss: 0.4083
# Epoch 5/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2641 - val_loss: 0.3620
# Epoch 6/30
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2218 - val_loss: 0.2737
# Epoch 7/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1844 - val_loss: 0.2293
# Epoch 8/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1903 - val_loss: 0.2372
# Epoch 9/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1678 - val_loss: 0.2721
# Epoch 10/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1782 - val_loss: 0.2632
# Epoch 11/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1597 - val_loss: 0.2478
# Epoch 12/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1628 - val_loss: 0.2383
# Epoch 13/30
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1670 - val_loss: 0.2416
# Epoch 14/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1575 - val_loss: 0.2459
# Epoch 15/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1500 - val_loss: 0.2497
# Epoch 16/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1532 - val_loss: 0.2537
# Epoch 17/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1488 - val_loss: 0.2475
# Epoch 18/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1425 - val_loss: 0.2360
# Epoch 19/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1514 - val_loss: 0.2302
# Epoch 20/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1555 - val_loss: 0.2361
# Epoch 21/30
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1533 - val_loss: 0.2422
# Epoch 22/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1542 - val_loss: 0.2441
# Epoch 23/30
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1578 - val_loss: 0.2463
# Epoch 24/30
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1491 - val_loss: 0.2443
# Epoch 25/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1496 - val_loss: 0.2373
# Epoch 26/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1401 - val_loss: 0.2302
# Epoch 27/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1523 - val_loss: 0.2284
# Epoch 28/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1488 - val_loss: 0.2242
# Epoch 29/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1377 - val_loss: 0.2292
# Epoch 30/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1534 - val_loss: 0.2373
#
#
# Plot for: LAKEWOOD--> FILLET QQQQ
#
#
# Model Forecasting initated: LAKEWOOD--> FILLET QQQQ
# Model prediction initiated : LAKEWOOD--> FILLET QQQQ
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_235_input'), name='lstm_235_input', description="created by layer 'lstm_235_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 877ms/step
# Model prediction completed : LAKEWOOD--> FILLET QQQQ
# Storing prediction into DataFrame : LAKEWOOD--> FILLET QQQQ
#
#
# Plotting prediction with original data : LAKEWOOD--> FILLET QQQQ
#
#
# Calculating MSE and RMSE : LAKEWOOD--> FILLET QQQQ
# 1/1 [==============================] - 0s 20ms/step
# Test Score: 2432.26 MSE
# Test Score: 49.32 RMSE
#
#
# Writing predicted results of LAKEWOOD and FILLET QQQQ
# Writing error matrices of LAKEWOOD and FILLET QQQQ
#
#
# LSTM Archtitecture RICHMOND CA--> CHICKEN XXXXX - O
# Model Training: RICHMOND CA--> CHICKEN XXXXX - O
# Epoch 1/30
# 6/6 [==============================] - 11s 216ms/step - loss: 0.3414 - val_loss: 0.1419
# Epoch 2/30
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3092 - val_loss: 0.1149
# Epoch 3/30
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2750 - val_loss: 0.0986
# Epoch 4/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2412 - val_loss: 0.0957
# Epoch 5/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2018 - val_loss: 0.1145
# Epoch 6/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1734 - val_loss: 0.1706
# Epoch 7/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1553 - val_loss: 0.1636
# Epoch 8/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1440 - val_loss: 0.1624
# Epoch 9/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1501 - val_loss: 0.1649
# Epoch 10/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1359 - val_loss: 0.1682
# Epoch 11/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1409 - val_loss: 0.1760
# Epoch 12/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1502 - val_loss: 0.1782
# Epoch 13/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1487 - val_loss: 0.1795
# Epoch 14/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1471 - val_loss: 0.1831
# Epoch 15/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1344 - val_loss: 0.1852
# Epoch 16/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1425 - val_loss: 0.1855
# Epoch 17/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1242 - val_loss: 0.1852
# Epoch 18/30
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1308 - val_loss: 0.1911
# Epoch 19/30
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1369 - val_loss: 0.1914
# Epoch 20/30
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1421 - val_loss: 0.1891
# Epoch 21/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1288 - val_loss: 0.1924
# Epoch 22/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1258 - val_loss: 0.1991
# Epoch 23/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1297 - val_loss: 0.2033
# Epoch 24/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1312 - val_loss: 0.2016
# Epoch 25/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1273 - val_loss: 0.2034
# Epoch 26/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1287 - val_loss: 0.2040
# Epoch 27/30
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1286 - val_loss: 0.2059
# Epoch 28/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1312 - val_loss: 0.2040
# Epoch 29/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1323 - val_loss: 0.2033
# Epoch 30/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1280 - val_loss: 0.2016
#
#
# Plot for: RICHMOND CA--> CHICKEN XXXXX - O
#
#
# Model Forecasting initated: RICHMOND CA--> CHICKEN XXXXX - O
# Model prediction initiated : RICHMOND CA--> CHICKEN XXXXX - O
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_241_input'), name='lstm_241_input', description="created by layer 'lstm_241_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 950ms/step
# Model prediction completed : RICHMOND CA--> CHICKEN XXXXX - O
# Storing prediction into DataFrame : RICHMOND CA--> CHICKEN XXXXX - O
#
#
# Plotting prediction with original data : RICHMOND CA--> CHICKEN XXXXX - O
#
#
# Calculating MSE and RMSE : RICHMOND CA--> CHICKEN XXXXX - O
# 1/1 [==============================] - 0s 16ms/step
# Test Score: 3979.65 MSE
# Test Score: 63.08 RMSE
#
#
# Writing predicted results of RICHMOND CA and CHICKEN XXXXX - O
# Writing error matrices of RICHMOND CA and CHICKEN XXXXX - O
#
#
# LSTM Archtitecture RICHMOND CA--> DRUMSTICKS NNNN
# Model Training: RICHMOND CA--> DRUMSTICKS NNNN
# Epoch 1/30
# 6/6 [==============================] - 12s 219ms/step - loss: 0.4788 - val_loss: 0.5951
# Epoch 2/30
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4442 - val_loss: 0.5566
# Epoch 3/30
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4070 - val_loss: 0.5117
# Epoch 4/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.3629 - val_loss: 0.4568
# Epoch 5/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.3122 - val_loss: 0.3772
# Epoch 6/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2457 - val_loss: 0.2126
# Epoch 7/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.2371 - val_loss: 0.2178
# Epoch 8/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2122 - val_loss: 0.2400
# Epoch 9/30
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1927 - val_loss: 0.2274
# Epoch 10/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1958 - val_loss: 0.2086
# Epoch 11/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1784 - val_loss: 0.1974
# Epoch 12/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1922 - val_loss: 0.1802
# Epoch 13/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1675 - val_loss: 0.1774
# Epoch 14/30
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1674 - val_loss: 0.1817
# Epoch 15/30
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1615 - val_loss: 0.1876
# Epoch 16/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1515 - val_loss: 0.1900
# Epoch 17/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1779 - val_loss: 0.1895
# Epoch 18/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1511 - val_loss: 0.1838
# Epoch 19/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1576 - val_loss: 0.1773
# Epoch 20/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1617 - val_loss: 0.1738
# Epoch 21/30
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1751 - val_loss: 0.1770
# Epoch 22/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1867 - val_loss: 0.1764
# Epoch 23/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1566 - val_loss: 0.1817
# Epoch 24/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1586 - val_loss: 0.1800
# Epoch 25/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1708 - val_loss: 0.1790
# Epoch 26/30
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1590 - val_loss: 0.1770
# Epoch 27/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1582 - val_loss: 0.1771
# Epoch 28/30
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1568 - val_loss: 0.1779
# Epoch 29/30
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1469 - val_loss: 0.1761
# Epoch 30/30
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1485 - val_loss: 0.1744
#
#
# Plot for: RICHMOND CA--> DRUMSTICKS NNNN
#
#
# Model Forecasting initated: RICHMOND CA--> DRUMSTICKS NNNN
# Model prediction initiated : RICHMOND CA--> DRUMSTICKS NNNN
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_247_input'), name='lstm_247_input', description="created by layer 'lstm_247_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 972ms/step
# Model prediction completed : RICHMOND CA--> DRUMSTICKS NNNN
# Storing prediction into DataFrame : RICHMOND CA--> DRUMSTICKS NNNN
#
#
# Plotting prediction with original data : RICHMOND CA--> DRUMSTICKS NNNN
#
#
# Calculating MSE and RMSE : RICHMOND CA--> DRUMSTICKS NNNN
# 1/1 [==============================] - 0s 33ms/step
# Test Score: 439335.93 MSE
# Test Score: 662.82 RMSE
#
#
# Writing predicted results of RICHMOND CA and DRUMSTICKS NNNN
# Writing error matrices of RICHMOND CA and DRUMSTICKS NNNN
#
#
# LSTM Archtitecture RICHMOND CA--> FILLET QQQQ
# Model Training: RICHMOND CA--> FILLET QQQQ
# Epoch 1/30
# 6/6 [==============================] - 11s 235ms/step - loss: 0.5455 - val_loss: 0.3277
# Epoch 2/30
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5039 - val_loss: 0.2893
# Epoch 3/30
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4628 - val_loss: 0.2480
# Epoch 4/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4187 - val_loss: 0.2090
# Epoch 5/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.3457 - val_loss: 0.1667
# Epoch 6/30
# 6/6 [==============================] - 0s 63ms/step - loss: 0.2826 - val_loss: 0.1377
# Epoch 7/30
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2405 - val_loss: 0.1712
# Epoch 8/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2191 - val_loss: 0.1550
# Epoch 9/30
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2058 - val_loss: 0.1616
# Epoch 10/30
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2178 - val_loss: 0.1731
# Epoch 11/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2088 - val_loss: 0.1839
# Epoch 12/30
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2136 - val_loss: 0.1829
# Epoch 13/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1938 - val_loss: 0.1904
# Epoch 14/30
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2171 - val_loss: 0.2009
# Epoch 15/30
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2134 - val_loss: 0.1843
# Epoch 16/30
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1980 - val_loss: 0.1773
# Epoch 17/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2056 - val_loss: 0.1736
# Epoch 18/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1955 - val_loss: 0.1818
# Epoch 19/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1992 - val_loss: 0.1904
# Epoch 20/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1963 - val_loss: 0.1969
# Epoch 21/30
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1956 - val_loss: 0.1909
# Epoch 22/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2135 - val_loss: 0.1782
# Epoch 23/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1745 - val_loss: 0.1775
# Epoch 24/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1683 - val_loss: 0.1731
# Epoch 25/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1957 - val_loss: 0.1702
# Epoch 26/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1766 - val_loss: 0.1781
# Epoch 27/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1941 - val_loss: 0.1659
# Epoch 28/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1714 - val_loss: 0.1599
# Epoch 29/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1784 - val_loss: 0.1666
# Epoch 30/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1739 - val_loss: 0.1560
#
#
# Plot for: RICHMOND CA--> FILLET QQQQ
#
#
# Model Forecasting initated: RICHMOND CA--> FILLET QQQQ
# Model prediction initiated : RICHMOND CA--> FILLET QQQQ
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_253_input'), name='lstm_253_input', description="created by layer 'lstm_253_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 1s/step
# Model prediction completed : RICHMOND CA--> FILLET QQQQ
# Storing prediction into DataFrame : RICHMOND CA--> FILLET QQQQ
#
#
# Plotting prediction with original data : RICHMOND CA--> FILLET QQQQ
#
#
# Calculating MSE and RMSE : RICHMOND CA--> FILLET QQQQ
# 1/1 [==============================] - 0s 18ms/step
# Test Score: 4241.30 MSE
# Test Score: 65.13 RMSE
#
#
# Writing predicted results of RICHMOND CA and FILLET QQQQ
# Writing error matrices of RICHMOND CA and FILLET QQQQ
#
#
# LSTM Archtitecture S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
# Model Training: S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
# Epoch 1/30
# 6/6 [==============================] - 12s 237ms/step - loss: 0.3295 - val_loss: 0.6163
# Epoch 2/30
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3142 - val_loss: 0.5993
# Epoch 3/30
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2975 - val_loss: 0.5803
# Epoch 4/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2775 - val_loss: 0.5573
# Epoch 5/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2533 - val_loss: 0.5257
# Epoch 6/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2274 - val_loss: 0.4645
# Epoch 7/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1651 - val_loss: 0.1926
# Epoch 8/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1689 - val_loss: 0.3539
# Epoch 9/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1638 - val_loss: 0.3783
# Epoch 10/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1618 - val_loss: 0.3546
# Epoch 11/30
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1569 - val_loss: 0.3007
# Epoch 12/30
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1570 - val_loss: 0.2909
# Epoch 13/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1555 - val_loss: 0.3197
# Epoch 14/30
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1502 - val_loss: 0.3455
# Epoch 15/30
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1561 - val_loss: 0.3498
# Epoch 16/30
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1515 - val_loss: 0.3389
# Epoch 17/30
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1493 - val_loss: 0.3216
# Epoch 18/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1448 - val_loss: 0.2998
# Epoch 19/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1564 - val_loss: 0.3031
# Epoch 20/30
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1493 - val_loss: 0.3060
# Epoch 21/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1451 - val_loss: 0.3130
# Epoch 22/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1640 - val_loss: 0.3276
# Epoch 23/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1421 - val_loss: 0.3280
# Epoch 24/30
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1396 - val_loss: 0.3153
# Epoch 25/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1385 - val_loss: 0.3123
# Epoch 26/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1534 - val_loss: 0.3213
# Epoch 27/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1482 - val_loss: 0.3278
# Epoch 28/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1474 - val_loss: 0.3077
# Epoch 29/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1479 - val_loss: 0.3002
# Epoch 30/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1466 - val_loss: 0.3051
#
#
# Plot for: S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
#
#
# Model Forecasting initated: S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
# Model prediction initiated : S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_259_input'), name='lstm_259_input', description="created by layer 'lstm_259_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 1s/step
# Model prediction completed : S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
# Storing prediction into DataFrame : S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
#
#
# Plotting prediction with original data : S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
#
#
# Calculating MSE and RMSE : S SAN FRANCISCO BUS CTR--> BEEF OOOO - GT
# 1/1 [==============================] - 0s 32ms/step
# Test Score: 124468.13 MSE
# Test Score: 352.80 RMSE
#
#
# Writing predicted results of S SAN FRANCISCO BUS CTR and BEEF OOOO - GT
# Writing error matrices of S SAN FRANCISCO BUS CTR and BEEF OOOO - GT
#
#
# LSTM Archtitecture S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
# Model Training: S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
# Epoch 1/30
# 6/6 [==============================] - 14s 299ms/step - loss: 0.3732 - val_loss: 0.1834
# Epoch 2/30
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3503 - val_loss: 0.1573
# Epoch 3/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3243 - val_loss: 0.1259
# Epoch 4/30
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2893 - val_loss: 0.0853
# Epoch 5/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2450 - val_loss: 0.0450
# Epoch 6/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1757 - val_loss: 0.1741
# Epoch 7/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1768 - val_loss: 0.1406
# Epoch 8/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1496 - val_loss: 0.1053
# Epoch 9/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1533 - val_loss: 0.1099
# Epoch 10/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1380 - val_loss: 0.1212
# Epoch 11/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1307 - val_loss: 0.1364
# Epoch 12/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1396 - val_loss: 0.1433
# Epoch 13/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1302 - val_loss: 0.1396
# Epoch 14/30
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1478 - val_loss: 0.1287
# Epoch 15/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1393 - val_loss: 0.1377
# Epoch 16/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1312 - val_loss: 0.1551
# Epoch 17/30
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1437 - val_loss: 0.1383
# Epoch 18/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1412 - val_loss: 0.1294
# Epoch 19/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1409 - val_loss: 0.1261
# Epoch 20/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1363 - val_loss: 0.1366
# Epoch 21/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1329 - val_loss: 0.1522
# Epoch 22/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1375 - val_loss: 0.1596
# Epoch 23/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1332 - val_loss: 0.1491
# Epoch 24/30
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1389 - val_loss: 0.1389
# Epoch 25/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1312 - val_loss: 0.1329
# Epoch 26/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1322 - val_loss: 0.1388
# Epoch 27/30
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1346 - val_loss: 0.1392
# Epoch 28/30
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1338 - val_loss: 0.1389
# Epoch 29/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1420 - val_loss: 0.1428
# Epoch 30/30
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1318 - val_loss: 0.1455
#
#
# Plot for: S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
#
#
# Model Forecasting initated: S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
# Model prediction initiated : S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_265_input'), name='lstm_265_input', description="created by layer 'lstm_265_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 1s 1s/step
# Model prediction completed : S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
# Storing prediction into DataFrame : S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
#
#
# Plotting prediction with original data : S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
#
#
# Calculating MSE and RMSE : S SAN FRANCISCO BUS CTR--> DRUMSTICKS NNNN
# 1/1 [==============================] - 0s 32ms/step
# Test Score: 17444.74 MSE
# Test Score: 132.08 RMSE
#
#
# Writing predicted results of S SAN FRANCISCO BUS CTR and DRUMSTICKS NNNN
# Writing error matrices of S SAN FRANCISCO BUS CTR and DRUMSTICKS NNNN

# %%
import pandas as pd
import os
import glob

# %%
# use glob to get all the csv files
# in the folder
path = 'C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Code\\ModelOut\\All_out\\Weekly\\Output\\'
out_files = glob.glob(os.path.join(path, "*.xlsx"))

dfs= []


for f in out_files:
    dfs.append(pd.read_excel(f))
df=pd.concat(dfs, ignore_index=True)

# %%
# df.to_excel('Output_all_LSTM_Weekly.xlsx', index=False)

# %%
path = 'C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Code\\ModelOut\\All_out\\Weekly\\Error\\'
error_files = glob.glob(os.path.join(path, "*.xlsx"))

len(error_files)

dfs_err= []


for f in error_files:
    dfs_err.append(pd.read_excel(f))
dfs_err=pd.concat(dfs_err, ignore_index=True)

# %%
# dfs_err.to_excel('Error_Output_all_LSTM_Weekly.xlsx', index=False)

# %% [markdown]
# ### Merging  Weekly resampled and forecasted data

# %%
df.head()
# Out:
#         Date  Forecasted_Qty Location               Item
# 0 2022-05-01       60.282200  FREMONT  CHICKEN XXXXX - O
# 1 2022-05-08       57.177780  FREMONT  CHICKEN XXXXX - O
# 2 2022-05-15       63.012772  FREMONT  CHICKEN XXXXX - O
# 3 2022-05-22       55.130318  FREMONT  CHICKEN XXXXX - O
# 4 2022-05-29       54.509056  FREMONT  CHICKEN XXXXX - O

# %%
# Weekly resampled data, checking dates are matchinh or not  
# data_df_new[(data_df_new['Date']>= '2022-03-27') & (data_df_new['Location']== 'FREMONT')]
# Out:
#     Location               Item       Date   Quantity      Amount
# 116  FREMONT  CHICKEN XXXXX - O 2022-03-27  42.472460  254.410000
# 117  FREMONT  CHICKEN XXXXX - O 2022-04-03  45.782553  274.237500
# 118  FREMONT  CHICKEN XXXXX - O 2022-04-10  71.829710  430.260000
# 119  FREMONT  CHICKEN XXXXX - O 2022-04-17  44.067114  263.962000
# 120  FREMONT  CHICKEN XXXXX - O 2022-04-24  43.085138  258.080000
# ..       ...                ...        ...        ...         ...
# 451  FREMONT        FILLET QQQQ 2022-10-30  39.327339  353.552857
# 452  FREMONT        FILLET QQQQ 2022-11-06  43.183700  388.221429
# 453  FREMONT        FILLET QQQQ 2022-11-13  46.081680  414.274286
# 454  FREMONT        FILLET QQQQ 2022-11-20  33.089784  297.477143
# 455  FREMONT        FILLET QQQQ 2022-11-27  44.452540  399.628333
#
# [108 rows x 5 columns]

# %%
# data_df_new.tail()
# Out:
#                      Location             Item       Date    Quantity  \
# 2122  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-10-30  113.512925
# 2123  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-11-06   97.404393
# 2124  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-11-13   93.240305
# 2125  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-11-20   94.381132
# 2126  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN 2022-11-27   88.660853
#
#           Amount
# 2122  146.431667
# 2123  125.651667
# 2124  120.280000
# 2125  121.751667
# 2126  114.372500

# %%
# data_df_new.shape
# Out:
# (2127, 5)

# %%
df_season
# Out:
#            Date    Quantity      Amount       Trend  seasonality  remainder  \
# 0    2020-01-05   37.023380  184.746667   37.023380            1          1
# 1    2020-01-12   41.889780  209.030000   41.889780            1          1
# 2    2020-01-19   86.101210  429.645000   86.101210            1          1
# 3    2020-01-26   63.834068  318.532000   63.834068            1          1
# 4    2020-02-02   45.320977  226.151667   45.320977            1          1
# ...         ...         ...         ...         ...          ...        ...
# 2122 2022-10-30  113.512925  146.431667  113.512925            1          1
# 2123 2022-11-06   97.404393  125.651667   97.404393            1          1
# 2124 2022-11-13   93.240305  120.280000   93.240305            1          1
# 2125 2022-11-20   94.381132  121.751667   94.381132            1          1
# 2126 2022-11-27   88.660853  114.372500   88.660853            1          1
#
#                      Location               Item
# 0                     FREMONT  CHICKEN XXXXX - O
# 1                     FREMONT  CHICKEN XXXXX - O
# 2                     FREMONT  CHICKEN XXXXX - O
# 3                     FREMONT  CHICKEN XXXXX - O
# 4                     FREMONT  CHICKEN XXXXX - O
# ...                       ...                ...
# 2122  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
# 2123  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
# 2124  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
# 2125  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
# 2126  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
#
# [2127 rows x 8 columns]

# %%
data_weekly= pd.read_excel('C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Dataset\\Final Output\\Weekly\\Data_Weekly.xlsx')
data_weekly.head()
# Out:
#   Location               Item       Date   Quantity      Amount
# 0  FREMONT  CHICKEN XXXXX - O 2020-01-05  37.023380  184.746667
# 1  FREMONT  CHICKEN XXXXX - O 2020-01-12  41.889780  209.030000
# 2  FREMONT  CHICKEN XXXXX - O 2020-01-19  86.101210  429.645000
# 3  FREMONT  CHICKEN XXXXX - O 2020-01-26  63.834068  318.532000
# 4  FREMONT  CHICKEN XXXXX - O 2020-02-02  45.320977  226.151667

# %%
data_merge= pd.merge(data_weekly, df, on= ['Date', 'Item', 'Location'], how='left')

# %%
data_merge
# Out:
#                      Location               Item       Date    Quantity  \
# 0                     FREMONT  CHICKEN XXXXX - O 2020-01-05   37.023380
# 1                     FREMONT  CHICKEN XXXXX - O 2020-01-12   41.889780
# 2                     FREMONT  CHICKEN XXXXX - O 2020-01-19   86.101210
# 3                     FREMONT  CHICKEN XXXXX - O 2020-01-26   63.834068
# 4                     FREMONT  CHICKEN XXXXX - O 2020-02-02   45.320977
# ...                       ...                ...        ...         ...
# 2122  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN 2022-10-30  113.512925
# 2123  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN 2022-11-06   97.404393
# 2124  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN 2022-11-13   93.240305
# 2125  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN 2022-11-20   94.381132
# 2126  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN 2022-11-27   88.660853
#
#           Amount  Forecasted_Qty
# 0     184.746667             NaN
# 1     209.030000             NaN
# 2     429.645000             NaN
# 3     318.532000             NaN
# 4     226.151667             NaN
# ...          ...             ...
# 2122  146.431667      115.714661
# 2123  125.651667      115.391205
# 2124  120.280000      115.308128
# 2125  121.751667      115.330795
# 2126  114.372500      115.218124
#
# [2127 rows x 6 columns]

# %%
# data_merge = data_merge.rename(columns= {'Pred_Quantity': 'Forecasted_Quantity'})
data_merge['Forecasted_Qty']= data_merge['Forecasted_Qty'].fillna(0)

# %%
data_merge.to_excel('Data_forecast_Weekly2.xlsx', index=False)

# %%
data_merge.shape
# Out:
# (2127, 9)
