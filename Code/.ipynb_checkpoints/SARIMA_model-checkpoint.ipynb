# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read Data 


data= pd.read_excel('C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Dataset\\Final Output\\Weekly\\Data_Weekly.xlsx', index_col ='Date',parse_dates = True)

# %%
data
# Out:
#                            Location               Item    Quantity      Amount
# Date
# 2020-01-05                  FREMONT  CHICKEN XXXXX - O   37.023380  184.746667
# 2020-01-12                  FREMONT  CHICKEN XXXXX - O   41.889780  209.030000
# 2020-01-19                  FREMONT  CHICKEN XXXXX - O   86.101210  429.645000
# 2020-01-26                  FREMONT  CHICKEN XXXXX - O   63.834068  318.532000
# 2020-02-02                  FREMONT  CHICKEN XXXXX - O   45.320977  226.151667
# ...                             ...                ...         ...         ...
# 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925  146.431667
# 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393  125.651667
# 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305  120.280000
# 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132  121.751667
# 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853  114.372500
#
# [2127 rows x 4 columns]

# %%
import copy

data2= copy.deepcopy(data)

# %%
for i in data['Location'].unique():
    df= data[data['Location']==i]
    print(i, ":-", list(df['Item'].unique()))
# Out:
# FREMONT :- ['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ']
# HAYWARD :- ['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ']
# LAKEWOOD :- ['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ']
# RICHMOND CA :- ['CHICKEN XXXXX - O', 'DRUMSTICKS NNNN', 'FILLET QQQQ']
# S SAN FRANCISCO BUS CTR :- ['BEEF OOOO - GT', 'DRUMSTICKS NNNN']

# %%
data3= data2[(data2['Location']== 'FREMONT') & (data2['Item']=='CHICKEN XXXXX - O')]

# %%
data3
# Out:
#            Location               Item   Quantity      Amount
# Date
# 2020-01-05  FREMONT  CHICKEN XXXXX - O  37.023380  184.746667
# 2020-01-12  FREMONT  CHICKEN XXXXX - O  41.889780  209.030000
# 2020-01-19  FREMONT  CHICKEN XXXXX - O  86.101210  429.645000
# 2020-01-26  FREMONT  CHICKEN XXXXX - O  63.834068  318.532000
# 2020-02-02  FREMONT  CHICKEN XXXXX - O  45.320977  226.151667
# ...             ...                ...        ...         ...
# 2022-10-30  FREMONT  CHICKEN XXXXX - O  38.625329  231.365714
# 2022-11-06  FREMONT  CHICKEN XXXXX - O  52.301170  313.284000
# 2022-11-13  FREMONT  CHICKEN XXXXX - O  41.523016  248.722857
# 2022-11-20  FREMONT  CHICKEN XXXXX - O  36.942523  221.285714
# 2022-11-27  FREMONT  CHICKEN XXXXX - O  28.980247  173.591667
#
# [152 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result=seasonal_decompose(data3['Quantity'], model='multiplicable', extrapolate_trend= 'freq')

# %%
result.plot()

# %%
season_out1= pd.DataFrame()

season_out1['Trend'] = result.trend
season_out1['seasonal']  = result.seasonal
season_out1['resid']  = result.resid

# %%
season_out1
# Out:
#                  Trend  seasonal     resid
# Date
# 2020-01-05  112.453897  1.085194  0.303385
# 2020-01-12  111.930588  0.761799  0.491268
# 2020-01-19  111.407280  1.325704  0.582974
# 2020-01-26  110.883972  1.158430  0.496952
# 2020-02-02  110.360663  0.881556  0.465838
# ...                ...       ...       ...
# 2022-10-30   25.356623  1.115853  1.365130
# 2022-11-06   24.786812  1.254536  1.681929
# 2022-11-13   24.217001  1.137524  1.507329
# 2022-11-20   23.647190  1.411738  1.106606
# 2022-11-27   23.077379  0.967083  1.298529
#
# [152 rows x 3 columns]

# %%
season_out1
# Out:
#                  Trend  seasonal     resid
# Date
# 2020-01-05  112.453897  1.085194  0.303385
# 2020-01-12  111.930588  0.761799  0.491268
# 2020-01-19  111.407280  1.325704  0.582974
# 2020-01-26  110.883972  1.158430  0.496952
# 2020-02-02  110.360663  0.881556  0.465838
# ...                ...       ...       ...
# 2022-10-30   25.356623  1.115853  1.365130
# 2022-11-06   24.786812  1.254536  1.681929
# 2022-11-13   24.217001  1.137524  1.507329
# 2022-11-20   23.647190  1.411738  1.106606
# 2022-11-27   23.077379  0.967083  1.298529
#
# [152 rows x 3 columns]

# %%
df = pd.concat([data3,season_out1], axis=1 )

# %%
df
# Out:
#            Location               Item   Quantity      Amount       Trend  \
# Date
# 2020-01-05  FREMONT  CHICKEN XXXXX - O  37.023380  184.746667  112.453897
# 2020-01-12  FREMONT  CHICKEN XXXXX - O  41.889780  209.030000  111.930588
# 2020-01-19  FREMONT  CHICKEN XXXXX - O  86.101210  429.645000  111.407280
# 2020-01-26  FREMONT  CHICKEN XXXXX - O  63.834068  318.532000  110.883972
# 2020-02-02  FREMONT  CHICKEN XXXXX - O  45.320977  226.151667  110.360663
# ...             ...                ...        ...         ...         ...
# 2022-10-30  FREMONT  CHICKEN XXXXX - O  38.625329  231.365714   25.356623
# 2022-11-06  FREMONT  CHICKEN XXXXX - O  52.301170  313.284000   24.786812
# 2022-11-13  FREMONT  CHICKEN XXXXX - O  41.523016  248.722857   24.217001
# 2022-11-20  FREMONT  CHICKEN XXXXX - O  36.942523  221.285714   23.647190
# 2022-11-27  FREMONT  CHICKEN XXXXX - O  28.980247  173.591667   23.077379
#
#             seasonal     resid
# Date
# 2020-01-05  1.085194  0.303385
# 2020-01-12  0.761799  0.491268
# 2020-01-19  1.325704  0.582974
# 2020-01-26  1.158430  0.496952
# 2020-02-02  0.881556  0.465838
# ...              ...       ...
# 2022-10-30  1.115853  1.365130
# 2022-11-06  1.254536  1.681929
# 2022-11-13  1.137524  1.507329
# 2022-11-20  1.411738  1.106606
# 2022-11-27  0.967083  1.298529
#
# [152 rows x 7 columns]

# %%
data2.head()
# Out:
#            Location               Item   Quantity      Amount
# Date
# 2020-01-05  FREMONT  CHICKEN XXXXX - O  37.023380  184.746667
# 2020-01-12  FREMONT  CHICKEN XXXXX - O  41.889780  209.030000
# 2020-01-19  FREMONT  CHICKEN XXXXX - O  86.101210  429.645000
# 2020-01-26  FREMONT  CHICKEN XXXXX - O  63.834068  318.532000
# 2020-02-02  FREMONT  CHICKEN XXXXX - O  45.320977  226.151667

# %%
# data_df = data2.reset_index()
# data_df
# Out:
#            Date                 Location               Item    Quantity  \
# 0    2020-01-05                  FREMONT  CHICKEN XXXXX - O   37.023380
# 1    2020-01-12                  FREMONT  CHICKEN XXXXX - O   41.889780
# 2    2020-01-19                  FREMONT  CHICKEN XXXXX - O   86.101210
# 3    2020-01-26                  FREMONT  CHICKEN XXXXX - O   63.834068
# 4    2020-02-02                  FREMONT  CHICKEN XXXXX - O   45.320977
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount
# 0     184.746667
# 1     209.030000
# 2     429.645000
# 3     318.532000
# 4     226.151667
# ...          ...
# 2122  146.431667
# 2123  125.651667
# 2124  120.280000
# 2125  121.751667
# 2126  114.372500
#
# [2127 rows x 5 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2127 non-null   datetime64[ns]
#  1   Location  2127 non-null   object
#  2   Item      2127 non-null   object
#  3   Quantity  2127 non-null   float64
#  4   Amount    2127 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 83.2+ KB

# %% [markdown]
# ### ALL ITEM AND LOCATIONS SEASONALITY

# %%
for i in data_df['Location'].unique():
    df= data_df[data_df['Location']==i]
    for j in df['Item'].unique():
        item_data= df[df["Item"]==j]
        
#         print(item_data)
        item_data.set_index('Date')
        result=seasonal_decompose(item_data['Quantity'], model='multiplicable', period=52, extrapolate_trend= 'freq')
        
        
        #Results
        se_out= pd.DataFrame()
        se_out['Trend'] = result.trend
        se_out['seasonality']  = result.seasonal
        se_out['remainder']  = result.resid
#         se_out['Date']= train_dates.values
        df_out = pd.concat([item_data,se_out], axis=1 )
        
#         predction_output = "ModelOut\seasonality\Weekly\season_" +i+"-"+j+".xlsx"
#         df_out.to_excel(predction_output, index= False)
#         print(df_out)

# %%
df_out
# Out:
#            Date                 Location             Item    Quantity  \
# 1975 2020-01-05  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN   45.462180
# 1976 2020-01-12  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN  109.512608
# 1977 2020-01-19  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN   64.205885
# 1978 2020-01-26  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN   62.563028
# 1979 2020-02-02  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN   90.672268
# ...         ...                      ...              ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR  DRUMSTICKS NNNN   88.660853
#
#           Amount       Trend  seasonality  remainder
# 1975   54.100000  176.021753     0.822388   0.314056
# 1976  130.320000  175.727830     0.889478   0.700630
# 1977   76.405000  175.433908     1.116553   0.327780
# 1978   74.450000  175.139985     0.731069   0.488623
# 1979  107.900000  174.846063     0.751758   0.689827
# ...          ...         ...          ...        ...
# 2122  146.431667  104.805140     1.063417   1.018495
# 2123  125.651667  104.246673     0.974794   0.958525
# 2124  120.280000  103.688207     0.849544   1.058495
# 2125  121.751667  103.129740     0.912276   1.003171
# 2126  114.372500  102.571273     0.916538   0.943096
#
# [152 rows x 8 columns]

# %%
import pandas as pd
import os
import glob

# %%
path = 'C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Code\\ModelOut\\seasonality\\Weekly'
out_files = glob.glob(os.path.join(path, "*.xlsx"))
   
dfs= []


for f in out_files:
    dfs.append(pd.read_excel(f))
df_season=pd.concat(dfs, ignore_index=True)

# %%
df_season.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         2127 non-null   datetime64[ns]
#  1   Location     2127 non-null   object
#  2   Item         2127 non-null   object
#  3   Quantity     2127 non-null   float64
#  4   Amount       2127 non-null   float64
#  5   Trend        2127 non-null   float64
#  6   seasonality  2127 non-null   float64
#  7   remainder    2127 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 133.1+ KB

# %%
df_season
# Out:
#            Date                 Location               Item    Quantity  \
# 0    2020-01-05                  FREMONT  CHICKEN XXXXX - O   37.023380
# 1    2020-01-12                  FREMONT  CHICKEN XXXXX - O   41.889780
# 2    2020-01-19                  FREMONT  CHICKEN XXXXX - O   86.101210
# 3    2020-01-26                  FREMONT  CHICKEN XXXXX - O   63.834068
# 4    2020-02-02                  FREMONT  CHICKEN XXXXX - O   45.320977
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount       Trend  seasonality  remainder
# 0     184.746667  112.453897     1.085194   0.303385
# 1     209.030000  111.930588     0.761799   0.491268
# 2     429.645000  111.407280     1.325704   0.582974
# 3     318.532000  110.883972     1.158430   0.496952
# 4     226.151667  110.360663     0.881556   0.465838
# ...          ...         ...          ...        ...
# 2122  146.431667  104.805140     1.063417   1.018495
# 2123  125.651667  104.246673     0.974794   0.958525
# 2124  120.280000  103.688207     0.849544   1.058495
# 2125  121.751667  103.129740     0.912276   1.003171
# 2126  114.372500  102.571273     0.916538   0.943096
#
# [2127 rows x 8 columns]

# %%
# df_season.to_excel('Seasonality_all_Weekly_SArima.xlsx', index=False)

# %%
df_season
# Out:
#            Date                 Location               Item    Quantity  \
# 0    2020-01-05                  FREMONT  CHICKEN XXXXX - O   37.023380
# 1    2020-01-12                  FREMONT  CHICKEN XXXXX - O   41.889780
# 2    2020-01-19                  FREMONT  CHICKEN XXXXX - O   86.101210
# 3    2020-01-26                  FREMONT  CHICKEN XXXXX - O   63.834068
# 4    2020-02-02                  FREMONT  CHICKEN XXXXX - O   45.320977
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount       Trend  seasonality  remainder
# 0     184.746667  112.453897     1.085194   0.303385
# 1     209.030000  111.930588     0.761799   0.491268
# 2     429.645000  111.407280     1.325704   0.582974
# 3     318.532000  110.883972     1.158430   0.496952
# 4     226.151667  110.360663     0.881556   0.465838
# ...          ...         ...          ...        ...
# 2122  146.431667  104.805140     1.063417   1.018495
# 2123  125.651667  104.246673     0.974794   0.958525
# 2124  120.280000  103.688207     0.849544   1.058495
# 2125  121.751667  103.129740     0.912276   1.003171
# 2126  114.372500  102.571273     0.916538   0.943096
#
# [2127 rows x 8 columns]

# %% [markdown]
# ### One item and location model

# %%
data3= data2[(data2['Location']== 'FREMONT') & (data2['Item']=='CHICKEN XXXXX - O')]

# %%
data3.head()
# Out:
#            Location               Item   Quantity      Amount
# Date
# 2020-01-05  FREMONT  CHICKEN XXXXX - O  37.023380  184.746667
# 2020-01-12  FREMONT  CHICKEN XXXXX - O  41.889780  209.030000
# 2020-01-19  FREMONT  CHICKEN XXXXX - O  86.101210  429.645000
# 2020-01-26  FREMONT  CHICKEN XXXXX - O  63.834068  318.532000
# 2020-02-02  FREMONT  CHICKEN XXXXX - O  45.320977  226.151667

# %%
# item_data= item_data.drop(['Location', 'Item', 'Amount'], axis=1)
# time_series = item_data.index
train = data3.iloc[:len(data3)-31]
test = data3.iloc[len(data3)-31:] # set 31 Months for testing
        
from statsmodels.tsa.statespace.sarimax import SARIMAX
  
model = SARIMAX(train['Quantity'],order = (1, 1, 1),seasonal_order =(2, 1, 1, 12))
  
result = model.fit(disp=False)
    
forecast = result.predict(start = 1, end = (len(item_data)), typ = 'levels').rename('Forecast')
# Out:
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)

# %%
forecast
# Out:
# 2020-01-12    37.006498
# 2020-01-19    41.882217
# 2020-01-26    86.059528
# 2020-02-02    63.846628
# 2020-02-09    45.340172
#                 ...
# 2022-11-06    40.164559
# 2022-11-13    37.625497
# 2022-11-20    45.287592
# 2022-11-27    44.978636
# 2022-12-04    37.918346
# Freq: W-SUN, Name: Forecast, Length: 152, dtype: float64

# %%
time_series = data3.index
df_forecast = pd.DataFrame()
df_forecast['Date']= time_series
df_forecast['Forcasted_Qty']= forecast.values

# %%
df_forecast
# Out:
#           Date  Forcasted_Qty
# 0   2020-01-05      37.006498
# 1   2020-01-12      41.882217
# 2   2020-01-19      86.059528
# 3   2020-01-26      63.846628
# 4   2020-02-02      45.340172
# ..         ...            ...
# 147 2022-10-30      40.164559
# 148 2022-11-06      37.625497
# 149 2022-11-13      45.287592
# 150 2022-11-20      44.978636
# 151 2022-11-27      37.918346
#
# [152 rows x 2 columns]

# %%
df= data3.reset_index()

# %%
merge= pd.merge(df, df_forecast, on=['Date'], how= 'outer')

# %%
merge
# Out:
#           Date Location               Item   Quantity      Amount  \
# 0   2020-01-05  FREMONT  CHICKEN XXXXX - O  37.023380  184.746667
# 1   2020-01-12  FREMONT  CHICKEN XXXXX - O  41.889780  209.030000
# 2   2020-01-19  FREMONT  CHICKEN XXXXX - O  86.101210  429.645000
# 3   2020-01-26  FREMONT  CHICKEN XXXXX - O  63.834068  318.532000
# 4   2020-02-02  FREMONT  CHICKEN XXXXX - O  45.320977  226.151667
# ..         ...      ...                ...        ...         ...
# 147 2022-10-30  FREMONT  CHICKEN XXXXX - O  38.625329  231.365714
# 148 2022-11-06  FREMONT  CHICKEN XXXXX - O  52.301170  313.284000
# 149 2022-11-13  FREMONT  CHICKEN XXXXX - O  41.523016  248.722857
# 150 2022-11-20  FREMONT  CHICKEN XXXXX - O  36.942523  221.285714
# 151 2022-11-27  FREMONT  CHICKEN XXXXX - O  28.980247  173.591667
#
#      Forcasted_Qty
# 0        37.006498
# 1        41.882217
# 2        86.059528
# 3        63.846628
# 4        45.340172
# ..             ...
# 147      40.164559
# 148      37.625497
# 149      45.287592
# 150      44.978636
# 151      37.918346
#
# [152 rows x 6 columns]

# %%
result_df = (result.get_prediction(start= 1, end=(len(data3))).summary_frame(alpha=0.05))

# %%
# result_df= result_df.rename(columns={'Quantity':'Date', 'mean':'Forecasted_Qty', 'mean_se':'MSE', 'mean_ci_lower':'yhat_lower', \
#                          'mean_ci_upper':'yhat_upper'})

# %%
# result_df.reset_index(inplace=True)

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 152 entries, 2020-01-12 to 2022-12-04
# Freq: W-SUN
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mean           152 non-null    float64
#  1   mean_se        152 non-null    float64
#  2   mean_ci_lower  152 non-null    float64
#  3   mean_ci_upper  152 non-null    float64
# dtypes: float64(4)
# memory usage: 5.9 KB

# %%
df1= pd.DataFrame()
df1= result_df

# %%
df1.index
# Out:
# DatetimeIndex(['2020-01-12', '2020-01-19', '2020-01-26', '2020-02-02',
#                '2020-02-09', '2020-02-16', '2020-02-23', '2020-03-01',
#                '2020-03-08', '2020-03-15',
#                ...
#                '2022-10-02', '2022-10-09', '2022-10-16', '2022-10-23',
#                '2022-10-30', '2022-11-06', '2022-11-13', '2022-11-20',
#                '2022-11-27', '2022-12-04'],
#               dtype='datetime64[ns]', length=152, freq='W-SUN')

# %%
merge1= pd.merge(df, result_df)

# %%
result_df.predicted_mean
# Out:
# 2020-01-12    37.006498
# 2020-01-19    41.882217
# 2020-01-26    86.059528
# 2020-02-02    63.846628
# 2020-02-09    45.340172
#                 ...
# 2022-11-06    40.164559
# 2022-11-13    37.625497
# 2022-11-20    45.287592
# 2022-11-27    44.978636
# 2022-12-04    37.918346
# Freq: W-SUN, Name: predicted_mean, Length: 152, dtype: float64

# %%
result_df.conf_int()
# Out:
#             lower Quantity  upper Quantity
# 2020-01-12    -1925.220569     1999.233565
# 2020-01-19    -1920.344430     2004.108864
# 2020-01-26    -1876.167104     2048.286160
# 2020-02-02    -1898.380004     2026.073260
# 2020-02-09    -1916.886459     2007.566804
# ...                    ...             ...
# 2022-11-06      -43.246699      123.575816
# 2022-11-13      -46.614953      121.865948
# 2022-11-20      -39.773620      130.348804
# 2022-11-27      -40.895460      130.852733
# 2022-12-04      -48.761175      124.597867
#
# [152 rows x 2 columns]

# %%
mn= pd.DataFrame()

mn= result_df.conf_int()

# %%
mn['lower Quantity']
# Out:
# 2020-01-12   -1925.220569
# 2020-01-19   -1920.344430
# 2020-01-26   -1876.167104
# 2020-02-02   -1898.380004
# 2020-02-09   -1916.886459
#                  ...
# 2022-11-06     -43.246699
# 2022-11-13     -46.614953
# 2022-11-20     -39.773620
# 2022-11-27     -40.895460
# 2022-12-04     -48.761175
# Freq: W-SUN, Name: lower Quantity, Length: 152, dtype: float64

# %%
df_fst = pd.DataFrame()
df_fst['Date']= time_series
df_fst['Forcasted_Qty']= forecast.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 result_df.index()
#
# File ~\anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'PredictionResults' object has no attribute 'index'

# %% [markdown]
# ### All in one Model

# %%
data_df
# Out:
#            Date                 Location               Item    Quantity  \
# 0    2020-01-05                  FREMONT  CHICKEN XXXXX - O   37.023380
# 1    2020-01-12                  FREMONT  CHICKEN XXXXX - O   41.889780
# 2    2020-01-19                  FREMONT  CHICKEN XXXXX - O   86.101210
# 3    2020-01-26                  FREMONT  CHICKEN XXXXX - O   63.834068
# 4    2020-02-02                  FREMONT  CHICKEN XXXXX - O   45.320977
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount
# 0     184.746667
# 1     209.030000
# 2     429.645000
# 3     318.532000
# 4     226.151667
# ...          ...
# 2122  146.431667
# 2123  125.651667
# 2124  120.280000
# 2125  121.751667
# 2126  114.372500
#
# [2127 rows x 5 columns]

# %%
data_df= data_df.set_index('Date')

# %%
data_df
# Out:
#                            Location               Item    Quantity      Amount
# Date
# 2020-01-05                  FREMONT  CHICKEN XXXXX - O   37.023380  184.746667
# 2020-01-12                  FREMONT  CHICKEN XXXXX - O   41.889780  209.030000
# 2020-01-19                  FREMONT  CHICKEN XXXXX - O   86.101210  429.645000
# 2020-01-26                  FREMONT  CHICKEN XXXXX - O   63.834068  318.532000
# 2020-02-02                  FREMONT  CHICKEN XXXXX - O   45.320977  226.151667
# ...                             ...                ...         ...         ...
# 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925  146.431667
# 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393  125.651667
# 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305  120.280000
# 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132  121.751667
# 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853  114.372500
#
# [2127 rows x 4 columns]

# %%
for i in data_df['Location'].unique():
    df= data_df[data_df['Location']==i]
    for j in df['Item'].unique():
        item_data= df[df["Item"]==j]
        
        item_data= item_data.drop(['Location', 'Item', 'Amount'], axis=1)
        time_series = item_data.index
        train = item_data.iloc[:len(df)-31]
        test = item_data.iloc[len(df)-31:] # set 31 Months for testing
        
        from statsmodels.tsa.statespace.sarimax import SARIMAX
  
        model = SARIMAX(train['Quantity'], 
                order = (1, 1, 1), 
                seasonal_order =(2, 1, 1, 12))
  
        result = model.fit()
    
        forecast = result.predict(start = 1, 
                          end = (len(item_data)), 
                          typ = 'levels').rename('Forecast')
        
        df_forecast = pd.DataFrame()
        df_forecast['Date']= time_series
        df_forecast['Forcasted_Qty']= forecast.values
        
        #Saving Results 
        df_forecast['Location']= i
        df_forecast['Item']=j
        
        print("\n")
        print(f'Writing predicted results of {i} and {j}')
        predction_output = "ModelOut\All_out\Weekly\Output\Output -" +i+"-"+j+".xlsx"
        df_forecast.to_excel(predction_output, index= False)
        
        # Load specific evaluation tools
        from sklearn.metrics import mean_squared_error
#         from statsmodels.tools.eval_measures import rmse
        import math
        

#         Calculate mean squared error
        MSE_Score= mean_squared_error(item_data["Quantity"], forecast.values)
        
        RMSE_Score= math.sqrt(mean_squared_error(item_data["Quantity"], forecast.values))
        
        col_names =  ['MSE_Score', 'RMSE_Score']
        Error_matric= pd.DataFrame(columns = col_names)
        
        my_out = {'MSE_Score': MSE_Score, 'RMSE_Score': RMSE_Score}
        Error_matric.loc[len(Error_matric)] = my_out 
        
        Error_matric['Location']=i
        Error_matric['Item']=j
        
        print(f'Writing error matrices of {i} and {j}')
        print("\n")
        Error_output = "ModelOut\All_out\Weekly\Error\Output_Error -" +i+"-"+j+".xlsx"
        Error_matric.to_excel(Error_output, index= False)
# Out:
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of FREMONT and CHICKEN XXXXX - O
# Writing error matrices of FREMONT and CHICKEN XXXXX - O
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of FREMONT and DRUMSTICKS NNNN
# Writing error matrices of FREMONT and DRUMSTICKS NNNN
#
#
#
#
# Writing predicted results of FREMONT and FILLET QQQQ
# Writing error matrices of FREMONT and FILLET QQQQ
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of HAYWARD and CHICKEN XXXXX - O
# Writing error matrices of HAYWARD and CHICKEN XXXXX - O
#
#
#
#
# Writing predicted results of HAYWARD and DRUMSTICKS NNNN
# Writing error matrices of HAYWARD and DRUMSTICKS NNNN
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of HAYWARD and FILLET QQQQ
# Writing error matrices of HAYWARD and FILLET QQQQ
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of LAKEWOOD and CHICKEN XXXXX - O
# Writing error matrices of LAKEWOOD and CHICKEN XXXXX - O
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of LAKEWOOD and DRUMSTICKS NNNN
# Writing error matrices of LAKEWOOD and DRUMSTICKS NNNN
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of LAKEWOOD and FILLET QQQQ
# Writing error matrices of LAKEWOOD and FILLET QQQQ
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of RICHMOND CA and CHICKEN XXXXX - O
# Writing error matrices of RICHMOND CA and CHICKEN XXXXX - O
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of RICHMOND CA and DRUMSTICKS NNNN
# Writing error matrices of RICHMOND CA and DRUMSTICKS NNNN
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of RICHMOND CA and FILLET QQQQ
# Writing error matrices of RICHMOND CA and FILLET QQQQ
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of S SAN FRANCISCO BUS CTR and BEEF OOOO - GT
# Writing error matrices of S SAN FRANCISCO BUS CTR and BEEF OOOO - GT
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\Ramshankar\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Writing predicted results of S SAN FRANCISCO BUS CTR and DRUMSTICKS NNNN
# Writing error matrices of S SAN FRANCISCO BUS CTR and DRUMSTICKS NNNN

# %%
import pandas as pd
import os
import glob

# %%
# use glob to get all the csv files
# in the folder
path = 'C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Code\\ModelOut\\All_out\\Weekly\\Output\\'
out_files = glob.glob(os.path.join(path, "*.xlsx"))

dfs= []


for f in out_files:
    dfs.append(pd.read_excel(f))
df=pd.concat(dfs, ignore_index=True)

# %%
df.to_excel('Output_all_SARIMA_Weekly.xlsx', index=False)

# %%
path = 'C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Code\\ModelOut\\All_out\\Weekly\\Error\\'
error_files = glob.glob(os.path.join(path, "*.xlsx"))

len(error_files)

dfs_err= []


for f in error_files:
    dfs_err.append(pd.read_excel(f))
dfs_err=pd.concat(dfs_err, ignore_index=True)

# %%
 dfs_err.to_excel('Error_Output_all_SARIMA_Weekly.xlsx', index=False)

# %%
df
# Out:
#            Date  Forcasted_Qty                 Location               Item
# 0    2020-01-05      37.009270                  FREMONT  CHICKEN XXXXX - O
# 1    2020-01-12      41.883290                  FREMONT  CHICKEN XXXXX - O
# 2    2020-01-19      86.066259                  FREMONT  CHICKEN XXXXX - O
# 3    2020-01-26      63.844131                  FREMONT  CHICKEN XXXXX - O
# 4    2020-02-02      45.337062                  FREMONT  CHICKEN XXXXX - O
# ...         ...            ...                      ...                ...
# 2122 2022-10-30     115.517915  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
# 2123 2022-11-06     118.614955  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
# 2124 2022-11-13     132.863461  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
# 2125 2022-11-20      87.941498  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
# 2126 2022-11-27      82.542661  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN
#
# [2127 rows x 4 columns]

# %%
merge1= pd.merge(df_season, df, on=['Date', 'Location', 'Item'], how= 'inner')

# %%
merge1
# Out:
#            Date                 Location               Item    Quantity  \
# 0    2020-01-05                  FREMONT  CHICKEN XXXXX - O   37.023380
# 1    2020-01-12                  FREMONT  CHICKEN XXXXX - O   41.889780
# 2    2020-01-19                  FREMONT  CHICKEN XXXXX - O   86.101210
# 3    2020-01-26                  FREMONT  CHICKEN XXXXX - O   63.834068
# 4    2020-02-02                  FREMONT  CHICKEN XXXXX - O   45.320977
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount  Trend  seasonality  remainder  Forcasted_Qty
# 0     184.746667    NaN     1.468230        NaN      37.009270
# 1     209.030000    NaN     0.959438        NaN      41.883290
# 2     429.645000    NaN     1.609120        NaN      86.066259
# 3     318.532000    NaN     1.455692        NaN      63.844131
# 4     226.151667    NaN     1.121424        NaN      45.337062
# ...          ...    ...          ...        ...            ...
# 2122  146.431667    NaN     1.036793        NaN     115.517915
# 2123  125.651667    NaN     0.979493        NaN     118.614955
# 2124  120.280000    NaN     0.811356        NaN     132.863461
# 2125  121.751667    NaN     0.896396        NaN      87.941498
# 2126  114.372500    NaN     0.927996        NaN      82.542661
#
# [2127 rows x 9 columns]

# %%
merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2127 entries, 0 to 2126
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           2127 non-null   datetime64[ns]
#  1   Location       2127 non-null   object
#  2   Item           2127 non-null   object
#  3   Quantity       2127 non-null   float64
#  4   Amount         2127 non-null   float64
#  5   Trend          1399 non-null   float64
#  6   seasonality    2127 non-null   float64
#  7   remainder      1399 non-null   float64
#  8   Forcasted_Qty  2127 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 166.2+ KB

# %%
#  merge1.to_excel('Final_Data_SARIMA_Weekly_BI.xlsx', index=False)

# %%
merge2 = merge1[merge1['Date'] >= '2022-05-01']

# %%
#  merge2.to_excel('Final_Data_SARIMA_6Mths_Forcst_Weekly.xlsx', index=False)

# %%
merge2
# Out:
#            Date                 Location               Item    Quantity  \
# 121  2022-05-01                  FREMONT  CHICKEN XXXXX - O   55.800344
# 122  2022-05-08                  FREMONT  CHICKEN XXXXX - O   41.938234
# 123  2022-05-15                  FREMONT  CHICKEN XXXXX - O   65.499995
# 124  2022-05-22                  FREMONT  CHICKEN XXXXX - O   27.730741
# 125  2022-05-29                  FREMONT  CHICKEN XXXXX - O   19.678630
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount      Trend  seasonality  remainder  Forcasted_Qty
# 121   334.244000  41.602612     1.075534   1.247074      46.707623
# 122   251.210000  41.707585     0.840754   1.195986      54.251304
# 123   392.345000  41.854859     1.170776   1.336662      49.945361
# 124   166.107143  41.889163     0.750883   0.881633      38.097019
# 125   117.875000  41.734644     0.590605   0.798364      43.473195
# ...          ...        ...          ...        ...            ...
# 2122  146.431667        NaN     1.036793        NaN     115.517915
# 2123  125.651667        NaN     0.979493        NaN     118.614955
# 2124  120.280000        NaN     0.811356        NaN     132.863461
# 2125  121.751667        NaN     0.896396        NaN      87.941498
# 2126  114.372500        NaN     0.927996        NaN      82.542661
#
# [434 rows x 9 columns]

# %%
merge2['stock_percentage_chng']= ((merge2["Forcasted_Qty"]-merge2["Quantity"])/merge2["Quantity"])*100
# Out:
# C:\Users\Ramshankar\AppData\Local\Temp\ipykernel_18212\1611085551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge2['stock_percentage_chng']= ((merge2["Forcasted_Qty"]-merge2["Quantity"])/merge2["Quantity"])*100

# %%
merge2
# Out:
#            Date                 Location               Item    Quantity  \
# 121  2022-05-01                  FREMONT  CHICKEN XXXXX - O   55.800344
# 122  2022-05-08                  FREMONT  CHICKEN XXXXX - O   41.938234
# 123  2022-05-15                  FREMONT  CHICKEN XXXXX - O   65.499995
# 124  2022-05-22                  FREMONT  CHICKEN XXXXX - O   27.730741
# 125  2022-05-29                  FREMONT  CHICKEN XXXXX - O   19.678630
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount      Trend  seasonality  remainder  Forcasted_Qty  \
# 121   334.244000  41.602612     1.075534   1.247074      46.707623
# 122   251.210000  41.707585     0.840754   1.195986      54.251304
# 123   392.345000  41.854859     1.170776   1.336662      49.945361
# 124   166.107143  41.889163     0.750883   0.881633      38.097019
# 125   117.875000  41.734644     0.590605   0.798364      43.473195
# ...          ...        ...          ...        ...            ...
# 2122  146.431667        NaN     1.036793        NaN     115.517915
# 2123  125.651667        NaN     0.979493        NaN     118.614955
# 2124  120.280000        NaN     0.811356        NaN     132.863461
# 2125  121.751667        NaN     0.896396        NaN      87.941498
# 2126  114.372500        NaN     0.927996        NaN      82.542661
#
#       stock_percentage_chng
# 121              -16.295099
# 122               29.360010
# 123              -23.747535
# 124               37.381899
# 125              120.915757
# ...                     ...
# 2122               1.766310
# 2123              21.775775
# 2124              42.495738
# 2125              -6.823010
# 2126              -6.900668
#
# [434 rows x 10 columns]

# %%
conditions = [
    (merge2['stock_percentage_chng'] <= 0),
    (merge2['stock_percentage_chng'] > 0) & (merge2['stock_percentage_chng'] <= 25),
    (merge2['stock_percentage_chng'] > 25)]


values = ['Understock', 'Onhand', 'Overstock']


merge2["Stocks"]=np.select(conditions, values)
# Out:
# C:\Users\Ramshankar\AppData\Local\Temp\ipykernel_18212\1667384382.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge2["Stocks"]=np.select(conditions, values)

# %%
merge2
# Out:
#            Date                 Location               Item    Quantity  \
# 121  2022-05-01                  FREMONT  CHICKEN XXXXX - O   55.800344
# 122  2022-05-08                  FREMONT  CHICKEN XXXXX - O   41.938234
# 123  2022-05-15                  FREMONT  CHICKEN XXXXX - O   65.499995
# 124  2022-05-22                  FREMONT  CHICKEN XXXXX - O   27.730741
# 125  2022-05-29                  FREMONT  CHICKEN XXXXX - O   19.678630
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount      Trend  seasonality  remainder  Forcasted_Qty  \
# 121   334.244000  41.602612     1.075534   1.247074      46.707623
# 122   251.210000  41.707585     0.840754   1.195986      54.251304
# 123   392.345000  41.854859     1.170776   1.336662      49.945361
# 124   166.107143  41.889163     0.750883   0.881633      38.097019
# 125   117.875000  41.734644     0.590605   0.798364      43.473195
# ...          ...        ...          ...        ...            ...
# 2122  146.431667        NaN     1.036793        NaN     115.517915
# 2123  125.651667        NaN     0.979493        NaN     118.614955
# 2124  120.280000        NaN     0.811356        NaN     132.863461
# 2125  121.751667        NaN     0.896396        NaN      87.941498
# 2126  114.372500        NaN     0.927996        NaN      82.542661
#
#       stock_percentage_chng      Stocks
# 121              -16.295099  Understock
# 122               29.360010   Overstock
# 123              -23.747535  Understock
# 124               37.381899   Overstock
# 125              120.915757   Overstock
# ...                     ...         ...
# 2122               1.766310      Onhand
# 2123              21.775775      Onhand
# 2124              42.495738   Overstock
# 2125              -6.823010  Understock
# 2126              -6.900668  Understock
#
# [434 rows x 11 columns]

# %%
def stock_flag(row):
    if row["Stocks"]== 'Overstock':
        return 1
    elif row["Stocks"]== 'Understock':
        return 2
    if row["Stocks"]== 'Onhand':
        return 3

# %%
merge2["stock_flag"] = merge2.apply(stock_flag,axis=1)
# Out:
# C:\Users\Ramshankar\AppData\Local\Temp\ipykernel_18212\1687910506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge2["stock_flag"] = merge2.apply(stock_flag,axis=1)

# %%
merge2
# Out:
#            Date                 Location               Item    Quantity  \
# 121  2022-05-01                  FREMONT  CHICKEN XXXXX - O   55.800344
# 122  2022-05-08                  FREMONT  CHICKEN XXXXX - O   41.938234
# 123  2022-05-15                  FREMONT  CHICKEN XXXXX - O   65.499995
# 124  2022-05-22                  FREMONT  CHICKEN XXXXX - O   27.730741
# 125  2022-05-29                  FREMONT  CHICKEN XXXXX - O   19.678630
# ...         ...                      ...                ...         ...
# 2122 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN  113.512925
# 2123 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   97.404393
# 2124 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   93.240305
# 2125 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   94.381132
# 2126 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN   88.660853
#
#           Amount      Trend  seasonality  remainder  Forcasted_Qty  \
# 121   334.244000  41.602612     1.075534   1.247074      46.707623
# 122   251.210000  41.707585     0.840754   1.195986      54.251304
# 123   392.345000  41.854859     1.170776   1.336662      49.945361
# 124   166.107143  41.889163     0.750883   0.881633      38.097019
# 125   117.875000  41.734644     0.590605   0.798364      43.473195
# ...          ...        ...          ...        ...            ...
# 2122  146.431667        NaN     1.036793        NaN     115.517915
# 2123  125.651667        NaN     0.979493        NaN     118.614955
# 2124  120.280000        NaN     0.811356        NaN     132.863461
# 2125  121.751667        NaN     0.896396        NaN      87.941498
# 2126  114.372500        NaN     0.927996        NaN      82.542661
#
#       stock_percentage_chng      Stocks  stock_flag
# 121              -16.295099  Understock           2
# 122               29.360010   Overstock           1
# 123              -23.747535  Understock           2
# 124               37.381899   Overstock           1
# 125              120.915757   Overstock           1
# ...                     ...         ...         ...
# 2122               1.766310      Onhand           3
# 2123              21.775775      Onhand           3
# 2124              42.495738   Overstock           1
# 2125              -6.823010  Understock           2
# 2126              -6.900668  Understock           2
#
# [434 rows x 12 columns]

# %%
merge2= merge2.drop(['Trend', 'seasonality', 'remainder'], axis=1)

# %%
# merge2.to_excel('Final_6Mths_Analysis_Weekly.xlsx', index=False)
