# %%
import pandas as pd
import numpy as np

# %%
data_forct = pd.read_excel('C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Code\\analysis\\Forecasted_invntry_stock_Anlys_6months.xlsx', sheet_name= 'Sheet1')

# %%
data_forct
# Out:
#           Date                 Location               Item  OH Quantity  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O        84.64
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O        65.47
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O        81.99
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O        82.37
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O        72.33
# ..         ...                      ...                ...          ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        55.94
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        81.92
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        38.68
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        76.53
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        68.86
#
#      On Order Quantity  In Transit Quantity  NSI Quantity  Quantity  Amount  \
# ...

# %%
data1= data_forct[['Date', 'Location', 'Item', 'Forecasted_Qty', 'Stock_Qty', 'Stocks']]

# %%
data1= data1.rename(columns= {'Stock_Qty': 'Stock_Qty1', 'Stocks': 'Stocks1'})

# %%
data1
# Out:
#           Date                 Location               Item  Forecasted_Qty  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O           46.71
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O           54.25
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O           49.95
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O           38.10
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O           43.47
# ..         ...                      ...                ...             ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          115.52
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          118.61
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          132.86
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           87.94
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           82.54
#
#      Stock_Qty1    Stocks1
# 0         24.00     Onhand
# ...

# %%
data_inv = pd.read_excel('C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Code\\analysis\\sales_invntry_Actual_stock_6months_weekly.xlsx', sheet_name= 'Sheet1')

# %%
data_inv
# Out:
#           Date                 Location               Item  OH Quantity  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O           85
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O           65
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O           82
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O           82
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O           72
# ..         ...                      ...                ...          ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           56
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           42
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           39
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           77
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           69
#
#      On Order Quantity  In Transit Quantity  NSI Quantity  Quantity  Amount  \
# ...

# %%
data2= data_inv[['Date', 'Location', 'Item', 'Forecasted_Qty', 'Stock_Qty', 'Stocks']]

# %%
data2= data2.rename(columns= {'Forecasted_Qty': 'Forecasted_Qty2', 'Stock_Qty': 'Stock_Qty2', 'Stocks': 'Stocks2'})

# %%
data2
# Out:
#           Date                 Location               Item  Forecasted_Qty2  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O            46.71
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O            54.25
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O            49.95
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O            38.10
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O            43.47
# ..         ...                      ...                ...              ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           115.52
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           118.61
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           132.86
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN            87.94
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN            82.54
#
#      Stock_Qty2    Stocks2
# 0            33  Overstock
# ...

# %%
df= pd.merge(data1, data2, on=['Date', 'Location', 'Item'], how='inner')

# %%
df
# Out:
#           Date                 Location               Item  Forecasted_Qty  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O           46.71
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O           54.25
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O           49.95
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O           38.10
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O           43.47
# ..         ...                      ...                ...             ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          115.52
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          118.61
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          132.86
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           87.94
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           82.54
#
#      Stock_Qty1    Stocks1  Forecasted_Qty2  Stock_Qty2    Stocks2
# ...

# %%
df['diff']= ((abs(df['Stock_Qty1']-df['Stock_Qty2']))/((df['Stock_Qty1']+df['Stock_Qty2'])/2)*100)

# %%
df['diff']= (abs(df['Stock_Qty1']-df['Stock_Qty2'])

# %%
def custom_calc(x):
    return ((abs(x[0] - x[1]))/ x[1]*100).round(2)

# %%
df['diff']= df[['Stock_Qty1', 'Stock_Qty2']].apply(custom_calc, axis=1)
# Out:
# C:\Users\Ramshankar\AppData\Local\Temp\ipykernel_5784\248686723.py:2: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((abs(x[0] - x[1]))/ x[1]*100).round(2)

# %%
df
# Out:
#           Date                 Location               Item  Forecasted_Qty  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O           46.71
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O           54.25
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O           49.95
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O           38.10
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O           43.47
# ..         ...                      ...                ...             ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          115.52
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          118.61
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          132.86
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           87.94
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           82.54
#
# ...

# %%
# def custom_calc(x):
#     return (((x[1] - x[0]) / x[0]) * 100).round(2)

# df['diff'] = df[['Stock_Qty1', 'Stock_Qty2']].apply(custom_calc, axis=1)

# %%
df
# Out:
#           Date                 Location               Item  Forecasted_Qty  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O           46.71
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O           54.25
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O           49.95
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O           38.10
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O           43.47
# ..         ...                      ...                ...             ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          115.52
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          118.61
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN          132.86
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           87.94
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN           82.54
#
# ...

# %%
df[df['Date']== '2022-07-10']
# Out:
#           Date                 Location               Item  Forecasted_Qty  \
# 10  2022-07-10                  FREMONT  CHICKEN XXXXX - O           29.85
# 41  2022-07-10                  FREMONT    DRUMSTICKS NNNN          694.35
# 72  2022-07-10                  FREMONT        FILLET QQQQ           43.89
# 103 2022-07-10                  HAYWARD  CHICKEN XXXXX - O           41.18
# 134 2022-07-10                  HAYWARD    DRUMSTICKS NNNN          595.95
# 165 2022-07-10                  HAYWARD        FILLET QQQQ           60.54
# 196 2022-07-10                 LAKEWOOD  CHICKEN XXXXX - O           40.00
# 227 2022-07-10                 LAKEWOOD    DRUMSTICKS NNNN          331.70
# 258 2022-07-10                 LAKEWOOD        FILLET QQQQ           57.65
# 289 2022-07-10              RICHMOND CA  CHICKEN XXXXX - O           62.45
# 320 2022-07-10              RICHMOND CA    DRUMSTICKS NNNN          816.66
# ...

# %%
df[df['Stocks1']== 'Onhand'].min()
# Out:
# Date               2022-05-01 00:00:00
# Location                       FREMONT
# Item                    BEEF OOOO - GT
# Forecasted_Qty                   19.51
# Stock_Qty1                        3.28
# Stocks1                         Onhand
# Forecasted_Qty2                  19.51
# Stock_Qty2                        -357
# Stocks2                         Onhand
# diff                           -366.67
# dtype: object

# %%
Onhand
max_change=  400
min= -2520.0

Overstock
max= 421.276596
min= -1440.0

Understock:
max= 494.275274
min=  -1200.0

# %%
df[df['diff']== -600.0]
# Out:
#           Date  Location               Item  Forecasted_Qty  Stock_Qty1  \
# 10  2022-07-10   FREMONT  CHICKEN XXXXX - O           29.85        -2.0
# 247 2022-11-27  LAKEWOOD    DRUMSTICKS NNNN          190.71        -6.0
#
#         Stocks1  Forecasted_Qty2  Stock_Qty2 Stocks2   diff
# 10   Understock            29.85           1  Onhand -600.0
# 247  Understock           190.71           3  Onhand -600.0

# %% [markdown]
# Onhand
# max_change=  600
# min= -2520.0
#
# Overstock
# max= 421.276596
# min= -1440.0
#
# Understock:
# max= 494.275274
# min=  -1200.0

# %%
data_forct['Percentage_change']= ((30-data_forct['Stock_Qty'])/30)*100

# %%
data_forct[data_forct['Stocks']== 'Onhand'].max()
# Out:
# Date                       2022-11-27 00:00:00
# Location               S SAN FRANCISCO BUS CTR
# Item                               FILLET QQQQ
# OH Quantity                            1019.95
# On Order Quantity                       761.65
# In Transit Quantity                     398.79
# NSI Quantity                                 0
# Quantity                                760.72
# Amount                                 1002.36
# Forecasted_Qty                          778.66
# Stock_Qty                                 30.0
# Stocks                                  Onhand
# Stock_flag                                   3
# Percentage_change                    89.066667
# dtype: object

# %% [markdown]
# Onhand
# max_change=  89.066667
# min= 0.0
#
# Overstock
# max= -3.333333
# min= -1153.333333
#
# Understock:
# max= 1460.0
# min=  100.0

# %% [markdown]
# ### Forecasted data

# %%
data_forct
# Out:
#           Date                 Location               Item  OH Quantity  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O        84.64
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O        65.47
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O        81.99
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O        82.37
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O        72.33
# ..         ...                      ...                ...          ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        55.94
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        81.92
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        38.68
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        76.53
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        68.86
#
#      On Order Quantity  In Transit Quantity  NSI Quantity  Quantity  Amount  \
# ...

# %%
data_forct["stock_percentage"] = (((data_forct["Forecasted_Qty"]-data_forct["Quantity"])/data_forct["Quantity"])*100).round(2)

# %%
data_forct
# Out:
#           Date                 Location               Item  OH Quantity  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O        84.64
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O        65.47
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O        81.99
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O        82.37
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O        72.33
# ..         ...                      ...                ...          ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        55.94
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        81.92
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        38.68
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        76.53
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        68.86
#
#      On Order Quantity  In Transit Quantity  NSI Quantity  Quantity  Amount  \
# ...

# %%
data_forct[data_forct['Stocks']== 'Understock'].min()
# Out:
# Date                   2022-05-01 00:00:00
# Location                           FREMONT
# Item                        BEEF OOOO - GT
# OH Quantity                          20.46
# On Order Quantity                      0.0
# In Transit Quantity                    0.0
# NSI Quantity                             0
# Quantity                             17.81
# Amount                               106.7
# Forecasted_Qty                       16.43
# Stock_Qty                           -408.0
# Stocks                          Understock
# Stock_flag                               2
# stock_percentage                -39.653816
# dtype: object

# %%
Onhand
max_change=  81.61
min= -31.02

Overstock
max= 120.884146
min= -36.03716

Understock:
max= 60.613016
min=  -39.653816

# %%
data_forct= data_forct.drop(columns= ['Stocks', 'Stock_flag'], axis=0)

# %%
data_forct
# Out:
#           Date                 Location               Item  OH Quantity  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O        84.64
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O        65.47
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O        81.99
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O        82.37
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O        72.33
# ..         ...                      ...                ...          ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        55.94
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        81.92
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        38.68
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        76.53
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        68.86
#
#      On Order Quantity  In Transit Quantity  NSI Quantity  Quantity  Amount  \
# ...

# %%
conditions = [
    (data_forct['stock_percentage'] <= 0),
    (data_forct['stock_percentage'] > 0) & (data_forct['stock_percentage'] <= 25),
    (data_forct['stock_percentage'] > 25)]

# %%
values = ['Understock', 'Onhand', 'Overstock']
data_forct["stock"]=np.select(conditions, values)

# %%
len(data_forct[data_forct['stock']== 'Onhand'])
# Out:
# 196

# %%
# Understock= 200 
# Onhand= 196
# Overstock= 84

# %%
def stock_flag(row):
    if row["stock"]== 'Overstock':
        return 1
    elif row["stock"]== 'Understock':
        return 2
    if row["stock"]== 'Onhand':
        return 3

# %%
data_forct["stock_flag"] = data_forct.apply(stock_flag, axis=1)

# %%
data_forct
# Out:
#           Date                 Location               Item  OH Quantity  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O        84.64
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O        65.47
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O        81.99
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O        82.37
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O        72.33
# ..         ...                      ...                ...          ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        55.94
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        81.92
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        38.68
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        76.53
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        68.86
#
#      On Order Quantity  In Transit Quantity  NSI Quantity  Quantity  Amount  \
# ...

# %%
data_forct= data_forct.rename(columns= {'Quantity': 'Actual_Qty'})

# %%
data_forct
# Out:
#           Date                 Location               Item  OH Quantity  \
# 0   2022-05-01                  FREMONT  CHICKEN XXXXX - O        84.64
# 1   2022-05-08                  FREMONT  CHICKEN XXXXX - O        65.47
# 2   2022-05-15                  FREMONT  CHICKEN XXXXX - O        81.99
# 3   2022-05-22                  FREMONT  CHICKEN XXXXX - O        82.37
# 4   2022-05-29                  FREMONT  CHICKEN XXXXX - O        72.33
# ..         ...                      ...                ...          ...
# 429 2022-10-30  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        55.94
# 430 2022-11-06  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        81.92
# 431 2022-11-13  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        38.68
# 432 2022-11-20  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        76.53
# 433 2022-11-27  S SAN FRANCISCO BUS CTR    DRUMSTICKS NNNN        68.86
#
#      On Order Quantity  In Transit Quantity  NSI Quantity  Actual_Qty  Amount  \
# ...

# %%
# data_forct.to_excel('forect_with_stock%22.xlsx', index=False)
