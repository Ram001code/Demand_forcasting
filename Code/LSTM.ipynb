# %%
import pandas as pd
import numpy as np

# %%
loc= 'C:\\Users\\Ramshankar\\OneDrive - iLink Systems Inc\\Documents\\Costco\\Dataset\\'


data= pd.read_excel(loc + 'Final_data_predictHQ_temp.xlsx', index_col=False)
data.head()
# Out:
#         Date Country State    Region District     Location Major Department  \
# 0 2022-11-14      US    CA  BAY AREA      BA2  RICHMOND CA       FRESH FOOD
# 1 2022-11-14      US    CA  BAY AREA      BA2  RICHMOND CA       FRESH FOOD
# 2 2022-11-14      US    CA  BAY AREA      BA2  RICHMOND CA       FRESH FOOD
# 3 2022-11-07      US    CA  BAY AREA      BA2  RICHMOND CA       FRESH FOOD
# 4 2022-11-07      US    CA  BAY AREA      BA2  RICHMOND CA       FRESH FOOD
#
#   Department Category       Group  ...   Amount Conferences_Impact  \
# 0    61 MEAT   6 MEAT  64 POULTRY  ...   898.59                 88
# 1    61 MEAT   6 MEAT  64 POULTRY  ...   790.93                 88
# 2    61 MEAT   6 MEAT  68 SEAFOOD  ...   583.46                 88
# 3    61 MEAT   6 MEAT  64 POULTRY  ...  1134.68                  0
# 4    61 MEAT   6 MEAT  64 POULTRY  ...   763.31                  0
#
#    Expose_Impact  Concerts_Impact  Festivals_Impacts  Performing_Arts_Impact  \
# ...

# %%
import copy
data_df= copy.deepcopy(data)

# %%
data_df.columns
# Out:
# Index(['Date', 'Country', 'State', 'Region', 'District', 'Location',
#        'Major Department', 'Department', 'Category', 'Group', 'Item Category',
#        'Item', 'Quantity', 'Amount', 'Conferences_Impact', 'Expose_Impact',
#        'Concerts_Impact', 'Festivals_Impacts', 'Performing_Arts_Impact',
#        'Community_Impact', 'Sports_Impact', 'Total_Impact_Active',
#        'Temperature (°F)'],
#       dtype='object')

# %%
data_df= data_df[['Date', 'Location', 'Item', 'Quantity', 'Amount', 'Conferences_Impact', 'Expose_Impact', 'Concerts_Impact',\
     'Festivals_Impacts', 'Performing_Arts_Impact', 'Community_Impact', 'Sports_Impact', 'Temperature (°F)']]

# %%
data_df.head()
# Out:
#         Date     Location               Item   Quantity   Amount  \
# 0 2022-11-14  RICHMOND CA    DRUMSTICKS NNNN  696.58142   898.59
# 1 2022-11-14  RICHMOND CA  CHICKEN XXXXX - O  132.04172   790.93
# 2 2022-11-14  RICHMOND CA        FILLET QQQQ   64.90101   583.46
# 3 2022-11-07  RICHMOND CA    DRUMSTICKS NNNN  879.59692  1134.68
# 4 2022-11-07  RICHMOND CA  CHICKEN XXXXX - O  127.43071   763.31
#
#    Conferences_Impact  Expose_Impact  Concerts_Impact  Festivals_Impacts  \
# 0                  88              0              145                  0
# 1                  88              0              145                  0
# 2                  88              0              145                  0
# 3                   0              0              180                220
# 4                   0              0              180                220
#
#    Performing_Arts_Impact  Community_Impact  Sports_Impact  Temperature (°F)
# ...

# %%
data_df.isnull().sum()
# Out:
# Date                      0
# Location                  0
# Item                      0
# Quantity                  0
# Amount                    0
# Conferences_Impact        0
# Expose_Impact             0
# Concerts_Impact           0
# Festivals_Impacts         0
# Performing_Arts_Impact    0
# Community_Impact          0
# Sports_Impact             0
# Temperature (°F)          0
# dtype: int64

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    352 non-null    datetime64[ns]
#  1   Location                352 non-null    object
#  2   Item                    352 non-null    object
#  3   Quantity                352 non-null    float64
#  4   Amount                  352 non-null    float64
#  5   Conferences_Impact      352 non-null    int64
#  6   Expose_Impact           352 non-null    int64
#  7   Concerts_Impact         352 non-null    int64
#  8   Festivals_Impacts       352 non-null    int64
#  9   Performing_Arts_Impact  352 non-null    int64
#  10  Community_Impact        352 non-null    int64
#  11  Sports_Impact           352 non-null    int64
#  12  Temperature (°F)        352 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(2)
# ...

# %%
data_df['Item'].nunique()
# Out:
# 3

# %%
#0.75*352

# %%
#converting categorical into numerical 
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
label1 = le.fit_transform(data_df['Location'])
label2 = le.fit_transform(data_df['Item'])

# %%
label2
# Out:
# array([1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 1, 0,
#        2, 1, 0, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 1, 0, 2, 1, 0, 2, 1, 0, 2,
#        1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 1, 0, 1, 0, 2, 1,
#        0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0,
#        2, 1, 0, 1, 2, 1, 0, 2, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 1, 0, 2, 1,
#        0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0,
#        1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 2,
#        1, 0, 2, 1, 2, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 2, 1,
#        0, 2, 0, 2, 1, 0, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0,
#        2, 1, 0, 2, 1, 2, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0,
#        2, 1, 0, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 2, 1, 0, 2, 0, 2, 1, 0, 2,
#        1, 0, 2, 1, 0, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0, 2, 1, 0,
#        1, 0, 2, 1, 0, 1, 0, 2, 0, 2, 0, 2, 1, 0, 2, 1, 0, 1, 0, 2, 1, 0,
# ...

# %%
data_df.drop("Location", axis=1, inplace=True)
data_df.drop("Item", axis=1, inplace=True)

# %%
data_df["Location"] = label1
data_df["Item"] = label2

# %%
data_df.head()
# Out:
#         Date  Location  Item   Quantity   Amount  Conferences_Impact  \
# 0 2022-11-14         4     1  696.58142   898.59                  88
# 1 2022-11-14         4     0  132.04172   790.93                  88
# 2 2022-11-14         4     2   64.90101   583.46                  88
# 3 2022-11-07         4     1  879.59692  1134.68                   0
# 4 2022-11-07         4     0  127.43071   763.31                   0
#
#    Expose_Impact  Concerts_Impact  Festivals_Impacts  Performing_Arts_Impact  \
# 0              0              145                  0                       0
# 1              0              145                  0                       0
# 2              0              145                  0                       0
# 3              0              180                220                       0
# 4              0              180                220                       0
#
#    Community_Impact  Sports_Impact  Temperature (°F)
# ...

# %%
data_df['Quantity'] = data_df['Quantity'].round(decimals = 2)

# %%
data_df.head()
# Out:
#         Date  Location  Item  Quantity   Amount  Conferences_Impact  \
# 0 2022-11-14         4     1    696.58   898.59                  88
# 1 2022-11-14         4     0    132.04   790.93                  88
# 2 2022-11-14         4     2     64.90   583.46                  88
# 3 2022-11-07         4     1    879.60  1134.68                   0
# 4 2022-11-07         4     0    127.43   763.31                   0
#
#    Expose_Impact  Concerts_Impact  Festivals_Impacts  Performing_Arts_Impact  \
# 0              0              145                  0                       0
# 1              0              145                  0                       0
# 2              0              145                  0                       0
# 3              0              180                220                       0
# 4              0              180                220                       0
#
#    Community_Impact  Sports_Impact  Temperature (°F)
# ...

# %%
data_df= data_df.set_index('Date')

# %%
data_df
# Out:
#             Location  Item  Quantity   Amount  Conferences_Impact  \
# Date
# 2022-11-14         4     1    696.58   898.59                  88
# 2022-11-14         4     0    132.04   790.93                  88
# 2022-11-14         4     2     64.90   583.46                  88
# 2022-11-07         4     1    879.60  1134.68                   0
# 2022-11-07         4     0    127.43   763.31                   0
# ...              ...   ...       ...      ...                 ...
# 2022-11-27         1     1    105.65   136.29                   0
# 2022-11-27         1     0     37.55   224.92                   0
# 2022-11-27         2     1    201.63   260.10                   0
# 2022-11-27         2     0     84.08   503.64                   0
# 2022-11-27         2     2     59.71   536.80                   0
#
#             Expose_Impact  Concerts_Impact  Festivals_Impacts  \
# Date
# 2022-11-14              0              145                  0
# ...

# %%
#Splitting it 
train_df,test_df= data_df[:264], data_df[264:]

# %%
train_df.shape,test_df.shape
# Out:
# ((264, 12), (88, 12))

# %%
train_df.tail()
# Out:
#             Location  Item  Quantity  Amount  Conferences_Impact  \
# Date
# 2022-11-06         0     1    223.12  287.82                   0
# 2022-11-06         0     0    163.04  976.61                   0
# 2022-11-06         0     2     21.21  190.68                   0
# 2022-11-13         1     1    143.95  185.69                   0
# 2022-11-13         1     0    119.30  714.62                   0
#
#             Expose_Impact  Concerts_Impact  Festivals_Impacts  \
# Date
# 2022-11-06              0                0                  0
# 2022-11-06              0                0                  0
# 2022-11-06              0                0                  0
# 2022-11-13           3000              610                  0
# 2022-11-13           3000              610                  0
#
#             Performing_Arts_Impact  Community_Impact  Sports_Impact  \
# Date
# 2022-11-06                       0                 0              0
# ...

# %%
test_df.head()
# Out:
#             Location  Item  Quantity  Amount  Conferences_Impact  \
# Date
# 2022-11-13         2     1    300.89  388.15                   0
# 2022-11-13         2     0     33.65  201.57                   0
# 2022-11-13         2     2     14.44  129.82                   0
# 2022-11-06         1     1    336.53  434.13                 647
# 2022-11-06         1     0    104.69  627.08                 647
#
#             Expose_Impact  Concerts_Impact  Festivals_Impacts  \
# Date
# 2022-11-13              0              240                  0
# 2022-11-13              0              240                  0
# 2022-11-13              0              240                  0
# 2022-11-06           3895              576                404
# 2022-11-06           3895              576                404
#
#             Performing_Arts_Impact  Community_Impact  Sports_Impact  \
# Date
# 2022-11-13                       0                 0              0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
import os

# %%
'''

Scaling the values 
All the columns in the data frame are on a different scale. Now we will scale the values to -1 to 1 for faster training of the models.
'''


train = train_df
scalers={}
for i in train_df.columns:
    scaler = MinMaxScaler(feature_range=(-1,1))
    s_s = scaler.fit_transform(train[i].values.reshape(-1,1))
    s_s=np.reshape(s_s,len(s_s))
    scalers['scaler_'+ i] = scaler
    train[i]=s_s

test = test_df
for i in train_df.columns:
    scaler = scalers['scaler_'+i]
    s_s = scaler.transform(test[i].values.reshape(-1,1))
    s_s=np.reshape(s_s,len(s_s))
    scalers['scaler_'+i] = scaler
    test[i]=s_s
# Out:
# C:\Users\Ramshankar\AppData\Local\Temp\ipykernel_15648\3684534845.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i]=s_s
# C:\Users\Ramshankar\AppData\Local\Temp\ipykernel_15648\3684534845.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i]=s_s
# C:\Users\Ramshankar\AppData\Local\Temp\ipykernel_15648\3684534845.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# __Converting the series to samples__
#
# Now we will make a function that will use a sliding window approach to transform our series into samples of input past observations and output future observations to use supervised learning algorithms.

# %%
def split_series(series, n_past, n_future):
  #
  # n_past ==> no of past observations
  #
  # n_future ==> no of future observations 
  #
  X, y = list(), list()
  for window_start in range(len(series)):
    past_end = window_start + n_past
    future_end = past_end + n_future
    if future_end > len(series):
      break
    # slicing the past and future parts of the window
    past, future = series[window_start:past_end, :], series[past_end:future_end, :]
    X.append(past)
    y.append(future)
  return np.array(X), np.array(y)

# %%
n_past = 10
n_future = 5 
n_features = 12

# %% [markdown]
# #Now convert both the train and test data into samples using the split_series function.

# %%
X_train, y_train = split_series(train.values,n_past, n_future)

# %%
X_train.shape
# Out:
# (250, 10, 12)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))

# %%
X_train.shape
# Out:
# (250, 10, 12)

# %%
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], n_features))

# %%
X_test.shape
# Out:
# (74, 10, 12)

# %% [markdown]
# ## Model Architecture

# %%
#!pip install tensorflow

# %%
import tensorflow as tf

# %%
#n_features ==> no of features at each timestep in the data.

encoder_inputs = tf.keras.layers.Input(shape=(n_past, n_features))
encoder_l1 = tf.keras.layers.LSTM(100, return_state=True)
encoder_outputs1 = encoder_l1(encoder_inputs)

encoder_states1 = encoder_outputs1[1:]

#
decoder_inputs = tf.keras.layers.RepeatVector(n_future)(encoder_outputs1[0])

#
decoder_l1 = tf.keras.layers.LSTM(100, return_sequences=True)(decoder_inputs,initial_state = encoder_states1)
decoder_outputs1 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(n_features))(decoder_l1)

#
model_e1d1 = tf.keras.models.Model(encoder_inputs,decoder_outputs1)

# %%
model_e1d1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 10, 12)]     0           []
#
#  lstm (LSTM)                    [(None, 100),        45200       ['input_1[0][0]']
#                                  (None, 100),
#                                  (None, 100)]
#
#  repeat_vector (RepeatVector)   (None, 5, 100)       0           ['lstm[0][0]']
#
#  lstm_1 (LSTM)                  (None, 5, 100)       80400       ['repeat_vector[0][0]',
#                                                                   'lstm[0][1]',
#                                                                   'lstm[0][2]']
#
#  time_distributed (TimeDistribu  (None, 5, 12)       1212        ['lstm_1[0][0]']
#  ted)
#
# ...
# Total params: 126,812
# Trainable params: 126,812
# Non-trainable params: 0
# ...

# %%
reduce_lr = tf.keras.callbacks.LearningRateScheduler(lambda x: 1e-3 * 0.90 ** x)
model_e1d1.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber())

# %%
history_e1d1=model_e1d1.fit(X_train,y_train,epochs=25,validation_data=(X_test,y_test),batch_size=32,verbose=0,callbacks=[reduce_lr])

# %%
#Prediction, 

pred_e1d1=model_e1d1.predict(X_test)
# Out:
# 3/3 [==============================] - 2s 8ms/step

# %%
pred_e1d1
# Out:
# array([[[ 7.05321217e+00,  1.99428022e+00,  6.58549219e+04, ...,
#           8.83962109e+03,  3.23080500e+05,  9.22314575e+02],
#         [ 7.14222479e+00,  1.98378897e+00,  6.25196016e+04, ...,
#           7.66798047e+03,  1.92423750e+05,  9.21968384e+02],
#         [ 7.13915491e+00,  1.97875667e+00,  6.15406328e+04, ...,
#           8.07593359e+03,  1.40117219e+05,  9.23161682e+02],
#         [ 7.10932827e+00,  1.97377014e+00,  6.20246250e+04, ...,
#           9.00954297e+03,  1.53733906e+05,  9.24918640e+02],
#         [ 7.07751894e+00,  1.96807981e+00,  6.28545664e+04, ...,
#           1.00680439e+04,  2.04500266e+05,  9.26851501e+02]],
#
#        [[ 7.21686268e+00,  2.05587411e+00,  5.88876875e+04, ...,
#           8.85694824e+03,  1.69393875e+05,  9.20525269e+02],
#         [ 7.30165148e+00,  2.03350592e+00,  5.81793789e+04, ...,
#           7.35286963e+03,  7.56798594e+04,  9.19002686e+02],
#         [ 7.28338957e+00,  2.02081108e+00,  5.87683828e+04, ...,
# ...

# %%
#Inverse Scaling of the predicted values
for index,i in enumerate(train_df.columns):
    scaler = scalers['scaler_'+i]
    pred_e1d1[:,:,index]=scaler.inverse_transform(pred_e1d1[:,:,index])
    pred_e1d1[:,:,index]=scaler.inverse_transform(pred_e1d1[:,:,index])
    y_train[:,:,index]=scaler.inverse_transform(y_train[:,:,index])
    y_test[:,:,index]=scaler.inverse_transform(y_test[:,:,index])

# %%
y_train
# Out:
# array([[[  3.  ,   0.  ,  59.41, ..., 198.  ,   0.  ,  54.4 ],
#         [  3.  ,   2.  ,  19.22, ..., 198.  ,   0.  ,  54.4 ],
#         [  0.  ,   1.  , 109.68, ...,   0.  ,   0.  ,  56.6 ],
#         [  0.  ,   0.  , 134.27, ...,   0.  ,   0.  ,  56.6 ],
#         [  0.  ,   2.  ,  24.38, ...,   0.  ,   0.  ,  56.6 ]],
#
#        [[  3.  ,   2.  ,  19.22, ..., 198.  ,   0.  ,  54.4 ],
#         [  0.  ,   1.  , 109.68, ...,   0.  ,   0.  ,  56.6 ],
#         [  0.  ,   0.  , 134.27, ...,   0.  ,   0.  ,  56.6 ],
#         [  0.  ,   2.  ,  24.38, ...,   0.  ,   0.  ,  56.6 ],
#         [  0.  ,   1.  , 187.9 , ...,   0.  ,   0.  ,  50.  ]],
#
#        [[  0.  ,   1.  , 109.68, ...,   0.  ,   0.  ,  56.6 ],
#         [  0.  ,   0.  , 134.27, ...,   0.  ,   0.  ,  56.6 ],
#         [  0.  ,   2.  ,  24.38, ...,   0.  ,   0.  ,  56.6 ],
#         [  0.  ,   1.  , 187.9 , ...,   0.  ,   0.  ,  50.  ],
#         [  0.  ,   0.  , 137.23, ...,   0.  ,   0.  ,  50.  ]],
#
#        ...,
#
# ...

# %%
y_test[0]
# Out:
# array([[  3.  ,   0.  , 113.53, 680.03,   0.  ,   0.  , 134.  ,   0.  ,
#           0.  ,   0.  ,   0.  ,  51.3 ],
#        [  3.  ,   2.  ,  24.18, 217.39,   0.  ,   0.  , 134.  ,   0.  ,
#           0.  ,   0.  ,   0.  ,  51.3 ],
#        [  0.  ,   1.  , 308.32, 397.73,   0.  ,   0.  ,   0.  ,   0.  ,
#           0.  ,   0.  ,   0.  ,  59.8 ],
#        [  0.  ,   0.  ,  74.04, 443.49,   0.  ,   0.  ,   0.  ,   0.  ,
#           0.  ,   0.  ,   0.  ,  59.8 ],
#        [  0.  ,   2.  ,  20.23, 181.85,   0.  ,   0.  ,   0.  ,   0.  ,
#           0.  ,   0.  ,   0.  ,  59.8 ]])

# %%
pred_e1d1[0]
# Out:
# array([[7.0532122e+00, 1.9942802e+00, 6.5854922e+04, 2.4995475e+05,
#         6.8162828e+04, 8.0222890e+06, 9.7220900e+06, 5.3241045e+03,
#         5.2823281e+05, 8.8396211e+03, 3.2308050e+05, 9.2231458e+02],
#        [7.1422248e+00, 1.9837890e+00, 6.2519602e+04, 2.4899581e+05,
#         5.6652598e+04, 4.2082590e+06, 6.7214980e+06, 3.1721511e+03,
#         4.4095306e+05, 7.6679805e+03, 1.9242375e+05, 9.2196838e+02],
#        [7.1391549e+00, 1.9787567e+00, 6.1540633e+04, 2.4958255e+05,
#         5.6412281e+04, 2.7938410e+06, 7.4661975e+06, 2.4550586e+03,
#         4.0325531e+05, 8.0759336e+03, 1.4011722e+05, 9.2316168e+02],
#        [7.1093283e+00, 1.9737701e+00, 6.2024625e+04, 2.5199023e+05,
#         6.4091906e+04, 2.5677130e+06, 9.7903670e+06, 2.4927612e+03,
#         3.8353081e+05, 9.0095430e+03, 1.5373391e+05, 9.2491864e+02],
#        [7.0775189e+00, 1.9680798e+00, 6.2854566e+04, 2.5509233e+05,
#         7.3846516e+04, 2.9045565e+06, 1.2441867e+07, 2.8649395e+03,
# ...

# %%
from sklearn.metrics import mean_absolute_error
for index,i in enumerate(train_df.columns):
  print(i)
  for j in range(1,6):
    print("Day ",j,":")
    print("MAE-E1D1 : ",mean_absolute_error(y_test[:,j-1,index],pred_e1d1[:,j-1,index]),end=", ")
  print()
  print()
# Out:
# Location
# Day  1 :
# MAE-E1D1 :  4.137578848245981, Day  2 :
# MAE-E1D1 :  4.190485129485259, Day  3 :
# MAE-E1D1 :  4.18730267962894, Day  4 :
# MAE-E1D1 :  4.141863752055812, Day  5 :
# MAE-E1D1 :  4.102287576005265,
#
# Item
# Day  1 :
# MAE-E1D1 :  1.005745768547058, Day  2 :
# MAE-E1D1 :  1.0253719461930764, Day  3 :
# MAE-E1D1 :  1.036332887572211, Day  4 :
# MAE-E1D1 :  1.0479699389354602, Day  5 :
# MAE-E1D1 :  1.0370046158094663,
#
# Quantity
# Day  1 :
# MAE-E1D1 :  53816.73374366555, Day  2 :
# MAE-E1D1 :  52523.06128167231, Day  3 :
# MAE-E1D1 :  52858.80250844595, Day  4 :
# MAE-E1D1 :  54343.55865498311, Day  5 :
# MAE-E1D1 :  55878.26217483108,
#
# Amount
# Day  1 :
# MAE-E1D1 :  224719.51875000002, Day  2 :
# MAE-E1D1 :  222827.4877195946, Day  3 :
# MAE-E1D1 :  223670.0501266892, Day  4 :
# MAE-E1D1 :  227071.38875844597, Day  5 :
# MAE-E1D1 :  231238.65040540538,
#
# Conferences_Impact
# Day  1 :
# MAE-E1D1 :  93313.89458403716, Day  2 :
# ...

# %%
for index,i in enumerate(train_df.columns):
  print(i)
  for j in range(1,6):
    print("Day ",j,":")
    print("Prediction : ",pred_e1d1[:,j-1,index], end=", ")
  print()
  print()
# Out:
# Location
# Day  1 :
# Prediction :  [7.053212  7.2168627 6.948195  6.2156544 5.6947927 4.9256687 5.148439
#  5.532502  6.110857  6.495693  6.447473  7.0515485 7.6321034 7.771015
#  7.6121407 7.7396317 7.274156  6.108973  5.5164366 4.706147  4.7836676
#  5.175115  5.466964  5.711298  5.7088337 6.9040704 7.3782864 7.7144747
#  7.4446287 7.514888  7.176345  5.9940147 5.3952045 4.6540275 4.791441
#  4.924575  5.295404  5.3085732 6.3310494 6.9113784 7.195236  7.267722
#  7.0314198 6.037576  5.38585   4.5806885 4.5649567 4.719956  4.9936
#  5.311407  5.3647213 6.49291   7.057084  7.2955623 7.109227  7.1919174
#  6.888712  5.849388  5.381093  4.60638   4.765147  4.9757705 5.1674542
#  5.4261074 5.3850594 6.4232597 6.998072  7.215902  7.2164183 7.2371826
#  6.916592  5.741106  5.201002  4.400613 ], Day  2 :
# Prediction :  [7.142225  7.3016515 6.9678354 6.2541595 5.767663  4.96298   5.2579937
#  5.6883926 6.243439  6.6252174 6.524852  7.0998087 7.6748705 7.7634706
# ...

# %%
''' 

final = pd.DataFrame(list(zip(train_df['Location'], train_df['Item'],train_df['Quantity'], train_df['Amount'], \
                              train_df['Conferences_Impact'],train_df['Expose_Impact'],train_df['Concerts_Impact'],\
                              train_df['Festivals_Impacts'], train_df['Performing_Arts_Impact'],\
                              train_df['Community_Impact'],train_df['Sports_Impact'], train_df['Temperature (°F)'], \
                              pred_e1d1)), 
               columns =['Location', 'Item', 'Quantity','Amount', 'Conferences_Impact', 'Expose_Impact', 'Concerts_Impact', \
                        'Festivals_Impacts', 'Performing_Arts_Impact', 'Community_Impact', 'Sports_Impact', 'Temperature (°F)']) 
    '''
# Out:
# " \n\nfinal = pd.DataFrame(list(zip(train_df['Location'], train_df['Item'],train_df['Quantity'], train_df['Amount'],                               train_df['Conferences_Impact'],train_df['Expose_Impact'],train_df['Concerts_Impact'],                              train_df['Festivals_Impacts'], train_df['Performing_Arts_Impact'],                              train_df['Community_Impact'],train_df['Sports_Impact'], train_df['Temperature (°F)'],                               pred_e1d1)), \n               columns =['Location', 'Item', 'Quantity','Amount', 'Conferences_Impact', 'Expose_Impact', 'Concerts_Impact',                         'Festivals_Impacts', 'Performing_Arts_Impact', 'Community_Impact', 'Sports_Impact', 'Temperature (°F)']) \n    "

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(history_e1d1.history['loss'])
plt.plot(history_e1d1.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train Loss', 'Validation Loss'], fancybox=True, shadow=True)
plt.show()

# %%
predicted_sales = pred_e1d1.flatten()

# %%
predicted_sales.shape
# Out:
# (4440,)
