# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("Inventory_updated2.xlsx")

# %%
data.sample(5)
# Out:
#              date  product_identifier  department_identifier  \
# 101729 2021-05-23                1508                     22
# 66501  2020-11-28                 337                     11
# 3708   2020-01-19                 743                     21
# 71513  2020-12-23                 972                     21
# 23283  2020-04-26                1629                     31
#
#                category_of_product  outlet        state  sales  week_id  \
# 101729  fast_moving_consumer_goods     113  Maharashtra      0      121
# 66501                       others     113  Maharashtra      3       96
# 3708    fast_moving_consumer_goods     113  Maharashtra      0       51
# 71513   fast_moving_consumer_goods     113  Maharashtra      2      100
# 23283              drinks_and_food     112  Maharashtra     11       65
#
#         sell_price year_month  net Sales  Temperature
# 101729        5.94    2013-05       0.00           38
# 66501         6.98    2012-11      20.94           27
# ...

# %%
data["date"].unique()
# Out:
# array(['2020-01-01T00:00:00.000000000', '2020-01-02T00:00:00.000000000',
#        '2020-01-03T00:00:00.000000000', '2020-01-04T00:00:00.000000000',
#        '2020-01-05T00:00:00.000000000', '2020-01-06T00:00:00.000000000',
#        '2020-01-07T00:00:00.000000000', '2020-01-08T00:00:00.000000000',
#        '2020-01-09T00:00:00.000000000', '2020-01-10T00:00:00.000000000',
#        '2020-01-11T00:00:00.000000000', '2020-01-12T00:00:00.000000000',
#        '2020-01-13T00:00:00.000000000', '2020-01-14T00:00:00.000000000',
#        '2020-01-15T00:00:00.000000000', '2020-01-16T00:00:00.000000000',
#        '2020-01-17T00:00:00.000000000', '2020-01-18T00:00:00.000000000',
#        '2020-01-19T00:00:00.000000000', '2020-01-20T00:00:00.000000000',
#        '2020-01-21T00:00:00.000000000', '2020-01-22T00:00:00.000000000',
#        '2020-01-23T00:00:00.000000000', '2020-01-24T00:00:00.000000000',
#        '2020-01-25T00:00:00.000000000', '2020-01-26T00:00:00.000000000',
# ...

# %%
holiday = pd.read_excel("Holiday_List_updated.xlsx")

# %%
holiday
# Out:
#          Date                  Holiday  Count
# 0  2020-01-26             Republic Day      1
# 1  2020-02-05               id-E-Milad      1
# 2  2020-02-19  Shivaji Maharaj Jayanti      1
# 3  2020-02-20            Mahashivratri      1
# 4  2020-03-08                     Holi      1
# 5  2020-03-23               Gudi Padwa      1
# 6  2020-04-01                Ram Navmi      1
# 7  2020-04-05          Mahavir Jayanti      1
# 8  2020-04-06              Good Friday      1
# 9  2020-04-14     Dr Babasaheb Jayanti      1
# 10 2020-05-01          Maharashtra Day      1
# 11 2020-05-06          Buddha pourmina      1
# 12 2020-08-15         Independence Day      1
# 13 2020-08-18           Parsi New Year      1
# 14 2020-08-20                Ramzan id      1
# 15 2020-09-29         Ganesh Chaturthi      1
# 16 2020-10-02   Mahatma Gandhi Jayanti      1
# 17 2020-10-24                   Dasara      1
# 18 2020-10-26                 Bakri id      1
# ...

# %%
holiday["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
holiday["Date"][1]
# Out:
# Timestamp('2020-02-05 00:00:00')

# %%
data[data["date"]=="2020-02-05 00:00:00"]
# Out:
#            date  product_identifier  department_identifier  \
# 7000 2020-02-05                  74                     11
# 7001 2020-02-05                 337                     11
# 7002 2020-02-05                 423                     12
# 7003 2020-02-05                 432                     12
# 7004 2020-02-05                 581                     21
# ...         ...                 ...                    ...
# 7195 2020-02-05                2932                     33
# 7196 2020-02-05                2935                     33
# 7197 2020-02-05                3004                     33
# 7198 2020-02-05                3008                     33
# 7199 2020-02-05                3021                     33
#
#              category_of_product  outlet        state  sales  week_id  \
# 7000                      others     111  Maharashtra      0       54
# 7001                      others     111  Maharashtra      2       54
# ...

# %%
data.iloc[7000]["date"] == holiday["Date"][1]
# Out:
# True

# %%
def is_holiday(row):
    if row["date"] in holiday["Date"].to_list():
        return 1
    else:
        return 0

# %%
data["Holiday"] = data.apply(is_holiday,axis=1)

# %%
data.sample(10)
# Out:
#              date  product_identifier  department_identifier  \
# 75267  2021-01-11                1173                     22
# 62594  2020-11-08                2853                     33
# 100487 2021-05-17                1753                     31
# 1339   2020-01-07                2332                     33
# 96810  2021-04-29                 868                     21
# 109928 2021-07-03                1472                     22
# 15924  2020-03-20                1322                     22
# 106963 2021-06-18                 972                     21
# 8602   2020-02-13                 423                     12
# 151019 2022-01-25                1196                     22
#
#                category_of_product  outlet        state  sales  week_id  \
# 75267   fast_moving_consumer_goods     112  Maharashtra      0      102
# 62594              drinks_and_food     114  Maharashtra      1       93
# 100487             drinks_and_food     112  Maharashtra      1      120
# ...

# %%
data.iloc[5105]["date"]
# Out:
# Timestamp('2020-01-26 00:00:00')

# %%
holiday[holiday["Date"]=="2021-12-25 00:00:00"]
# Out:
#          Date    Holiday  Count
# 47 2021-12-25  Christmas      1

# %%
#data.to_excel("Inventory_updated3.xlsx")

# %%
data[data["Holiday"]==1]
# Out:
#              date  product_identifier  department_identifier  \
# 5000   2020-01-26                  74                     11
# 5001   2020-01-26                 337                     11
# 5002   2020-01-26                 423                     12
# 5003   2020-01-26                 432                     12
# 5004   2020-01-26                 581                     21
# ...           ...                 ...                    ...
# 157795 2022-02-27                2932                     33
# 157796 2022-02-27                2935                     33
# 157797 2022-02-27                3004                     33
# 157798 2022-02-27                3008                     33
# 157799 2022-02-27                3021                     33
#
#                category_of_product  outlet        state  sales  week_id  \
# 5000                        others     111  Maharashtra      1       52
# 5001                        others     111  Maharashtra      1       52
# ...
